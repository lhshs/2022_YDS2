# %%
import FinanceDataReader as fdr

import pandas as pd

# %%
# !pip install -U finance-datareader

# %%
df = fdr.DataReader('005930')
df['Close'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df = df.fillna(-1)

# %%
df
# Out:
#              Open   High    Low  Close    Volume    Change
# Date
# 1998-05-25    970   1020    912    912    456620 -1.000000
# 1998-05-26    875    893    837    847    422200 -0.071272
# 1998-05-27    921    921    822    873    596090  0.030697
# 1998-05-28    876    977    875    977    835549  0.119129
# 1998-05-29    977   1007    969    996    717510  0.019447
# ...           ...    ...    ...    ...       ...       ...
# 2022-07-26  60800  61900  60800  61700   6597211  0.009820
# 2022-07-27  61300  61900  61200  61800   7320997  0.001621
# 2022-07-28  62300  62600  61600  61900  10745302  0.001618
# 2022-07-29  62400  62600  61300  61400  15093120 -0.008078
# 2022-08-01  61000  61700  60300  61300  13114555 -0.001629
#
# [6000 rows x 6 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 6000 entries, 1998-05-25 to 2022-08-01
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Open    6000 non-null   int64
#  1   High    6000 non-null   int64
#  2   Low     6000 non-null   int64
#  3   Close   6000 non-null   int64
#  4   Volume  6000 non-null   int64
#  5   Change  6000 non-null   float64
# dtypes: float64(1), int64(5)
# memory usage: 328.1 KB

# %%
# labeling 하기
# 하락 = 0, 상승 = 1
df.loc[df.Change > 0, 'Change'] = 1
df.loc[df.Change < 0, 'Change'] = 0
df
# Out:
#              Open   High    Low  Close    Volume  Change
# Date
# 1998-05-23   1051   1068   1033   1033    285990     0.0
# 1998-05-25    970   1020    912    912    456620     0.0
# 1998-05-26    875    893    837    847    422200     0.0
# 1998-05-27    921    921    822    873    596090     1.0
# 1998-05-28    876    977    875    977    835549     1.0
# ...           ...    ...    ...    ...       ...     ...
# 2022-07-25  60900  61900  60800  61100   9193681     0.0
# 2022-07-26  60800  61900  60800  61700   6597211     1.0
# 2022-07-27  61300  61900  61200  61800   7320997     1.0
# 2022-07-28  62300  62600  61600  61900  10745302     1.0
# 2022-07-29  62400  62600  61800  62100   6760350     1.0
#
# [6000 rows x 6 columns]

# %%
df = df.astype({'Change':'int'})
df
# Out:
#              Open   High    Low  Close    Volume  Change
# Date
# 1998-05-23   1051   1068   1033   1033    285990       0
# 1998-05-25    970   1020    912    912    456620       0
# 1998-05-26    875    893    837    847    422200       0
# 1998-05-27    921    921    822    873    596090       1
# 1998-05-28    876    977    875    977    835549       1
# ...           ...    ...    ...    ...       ...     ...
# 2022-07-25  60900  61900  60800  61100   9193681       0
# 2022-07-26  60800  61900  60800  61700   6597211       1
# 2022-07-27  61300  61900  61200  61800   7320997       1
# 2022-07-28  62300  62600  61600  61900  10745302       1
# 2022-07-29  62400  62600  61800  62100   6760350       1
#
# [6000 rows x 6 columns]

# %%
df.Change.value_counts()
# Out:
# 0    3062
# 1    2938
# Name: Change, dtype: int64

# %%
df
# Out:
#              Open   High    Low  Close    Volume  Change
# Date
# 1998-05-23   1051   1068   1033   1033    285990       0
# 1998-05-25    970   1020    912    912    456620       0
# 1998-05-26    875    893    837    847    422200       0
# 1998-05-27    921    921    822    873    596090       1
# 1998-05-28    876    977    875    977    835549       1
# ...           ...    ...    ...    ...       ...     ...
# 2022-07-25  60900  61900  60800  61100   9193681       0
# 2022-07-26  60800  61900  60800  61700   6597211       1
# 2022-07-27  61300  61900  61200  61800   7320997       1
# 2022-07-28  62300  62600  61600  61900  10745302       1
# 2022-07-29  62400  62600  61800  62100   6760350       1
#
# [6000 rows x 6 columns]

# %%
df.to_csv('005930_Label.csv')

# %%
data = pd.read_csv('005930_Label.csv')

# %%
data.set_index('Date')
# Out:
#              Open   High    Low  Close    Volume  Change
# Date
# 1998-05-21   1130   1139   1061   1061    605730       0
# 1998-05-22   1029   1042   1014   1026    465530       0
# 1998-05-23   1051   1068   1033   1033    285990       1
# 1998-05-25    970   1020    912    912    456620       0
# 1998-05-26    875    893    837    847    422200       0
# ...           ...    ...    ...    ...       ...     ...
# 2022-07-21  61100  61900  60700  61800  12291374       1
# 2022-07-22  61800  62200  61200  61300  10261310       0
# 2022-07-25  60900  61900  60800  61100   9193681       0
# 2022-07-26  60800  61900  60800  61700   6597211       1
# 2022-07-27  61300  61900  61300  61300   2685024       0
#
# [6000 rows x 6 columns]
