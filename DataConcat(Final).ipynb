# %%
import pandas as pd

# %%
df1998_2010 = pd.read_csv('data(concat)/1998_2010.csv', index_col = 0).reset_index().drop(columns='index')
df2011_2016 = pd.read_csv('data(concat)/2011_2016.csv', index_col = 0).reset_index().drop(columns='index')
df2017_2022 = pd.read_csv('data(concat)/2017_2022.csv', index_col = 0).reset_index().drop(columns='index')

# %%
df1998_2010
# Out:
#            언론사           날짜                                     제목
# 0         연합뉴스  1998.05.20.                             주가 사흘째 상승세
# 1         연합뉴스  1998.05.20.                아남텔레콤, PDA 데이터 전송서비스 개시
# 2         연합뉴스  1998.05.20.                <회전목마> 삼성전자, 사이버 사외보 제작
# 3         연합뉴스  1998.05.20.               <주식시황> 사흘째 상승, 3백70선 다가서
# 4         연합뉴스  1998.05.20.                  -춘계승마- 신창무,싼졸쥬마장마술 우승
# ...        ...          ...                                    ...
# 667057  파이낸셜뉴스      A18면 2단        [CES2011]세계 최대 가전쇼 열리는 라스베이거스는?
# 667058    매일경제       9면 TOP         갤럭시 플레이어 미리 만나볼까, 본격출시전 체험단 모집
# 667059     뉴스핌        9면 3단                  <스페셜인터뷰> 천정훈 MIT 석좌교수
# 667060  헤럴드POP       12면 3단                     갤럭시S 닮은꼴 'N스크린' 공개
# 667061   미디어오늘       4면 TOP  “2011년 1000만원이 1억 될 종목” 묻지마 쩜상이 기대된다!
#
# [667062 rows x 3 columns]

# %%
df2011_2016
# Out:
#             언론사           날짜                                         제목
# 0         에너지경제  2011.01.01.                         신년특집/ 지열, 솟아라 2011
# 1          서울신문  2011.01.01.        [서울신문 신년특집] 새해 경제 기상도 - 산업계 이렇게 바뀐다
# 2          동아일보      B4면 TOP           [경제계 신년사]“미래 성장동력 발굴해 경제성장 이어가자”
# 3          동아일보  2011.01.01.  [인문사회]‘제2의 개항’ FTA 시작과 끝… 막전막후 협상비화 상세 소개
# 4         헤럴드경제      A18면 2단                   실적·성장... 양 날개로... ‘퀀텀점프’
# ...         ...          ...                                        ...
# 1471341  아시아투데이  2017.01.01.                 한국 경제리더 새해 화두는 '위기 극복과 혁신'
# 1471342    전자신문      A12면 1단     특검, 이번 주 삼성 수뇌부 줄소환…최순실 특혜지원 관련, 대상자는?
# 1471343    매일경제  2017.01.01.       [한경매물마당] 광진구 역세권 수익형 근린생활시설 빌딩 등 15건
# 1471344   위클리오늘      A4면 TOP          [이코노 브리핑] 삼성, 분리세탁가능 ‘플렉스워시’ 공개 외
# 1471345    신아일보  2017.01.01.              "트럼프 공약처럼…한국, 법인세율 내려야 경제 성장"
#
# [1471346 rows x 3 columns]

# %%
df2017_2022
# Out:
#               언론사           날짜  \
# 0            아주경제  2017.01.01.
# 1        중앙SUNDAY  2017.01.01.
# 2            IT조선  2017.01.01.
# 3            전자신문       33면 1단
# 4             EBN  2017.01.01.
# ...           ...          ...
# 1713557      한국경제  2022.07.21.
# 1713558      한국경제  2022.07.21.
# 1713559      한국경제  2022.07.21.
# 1713560      한국경제  2022.07.21.
# 1713561      한국경제  2022.07.21.
#
#                                                       제목
# 0          특검,문형표 구속에 새해 첫날 안종범 재소환..삼성 합병에 박근혜 역할 집중...
# 1                                                 1308조원
# 2              [2017 스마트폰 트렌드] ①스마트폰 시장 ‘흐림’ 전망...탈출구 있나
# 3                               [신년기획]인공지능, 올해 경쟁력 확보 원년
# 4        [주간증시전망] CES發 IT섹터 관심 다양화·삼성전자 실적 발표 등 대장주 상...
# ...                                                  ...
# 1713557                    디지털이미지뱅크, 한투등 3개사서 20억원 투자 유치
# 1713558                                     [코스닥공시] 세보기계
# 1713559                               전자.통신업체 신용등급도 급상승세
# ...

# %%
df = pd.concat([df1998_2010, df2011_2016, df2017_2022])
df
# Out:
#           언론사           날짜                             제목
# 0        연합뉴스  1998.05.20.                     주가 사흘째 상승세
# 1        연합뉴스  1998.05.20.        아남텔레콤, PDA 데이터 전송서비스 개시
# 2        연합뉴스  1998.05.20.        <회전목마> 삼성전자, 사이버 사외보 제작
# 3        연합뉴스  1998.05.20.       <주식시황> 사흘째 상승, 3백70선 다가서
# 4        연합뉴스  1998.05.20.          -춘계승마- 신창무,싼졸쥬마장마술 우승
# ...       ...          ...                            ...
# 1713557  한국경제  2022.07.21.  디지털이미지뱅크, 한투등 3개사서 20억원 투자 유치
# 1713558  한국경제  2022.07.21.                   [코스닥공시] 세보기계
# 1713559  한국경제  2022.07.21.             전자.통신업체 신용등급도 급상승세
# 1713560  한국경제  2022.07.21.  종합주가 폭락세, 916.01(-37.21) 전장마감
# 1713561  한국경제  2022.07.21.  산자부, 수치제어장치 산.학.연 공동연구 개발에 성공
#
# [3851970 rows x 3 columns]

# %%
df.drop_duplicates()
# Out:
#           언론사           날짜                             제목
# 0        연합뉴스  1998.05.20.                     주가 사흘째 상승세
# 1        연합뉴스  1998.05.20.        아남텔레콤, PDA 데이터 전송서비스 개시
# 2        연합뉴스  1998.05.20.        <회전목마> 삼성전자, 사이버 사외보 제작
# 3        연합뉴스  1998.05.20.       <주식시황> 사흘째 상승, 3백70선 다가서
# 4        연합뉴스  1998.05.20.          -춘계승마- 신창무,싼졸쥬마장마술 우승
# ...       ...          ...                            ...
# 1713557  한국경제  2022.07.21.  디지털이미지뱅크, 한투등 3개사서 20억원 투자 유치
# 1713558  한국경제  2022.07.21.                   [코스닥공시] 세보기계
# 1713559  한국경제  2022.07.21.             전자.통신업체 신용등급도 급상승세
# 1713560  한국경제  2022.07.21.  종합주가 폭락세, 916.01(-37.21) 전장마감
# 1713561  한국경제  2022.07.21.  산자부, 수치제어장치 산.학.연 공동연구 개발에 성공
#
# [3704293 rows x 3 columns]
