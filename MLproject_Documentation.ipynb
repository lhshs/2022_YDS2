# %% [markdown]
# train_Transaction&nbsp;&nbsp;(590540, 394)
# </br>train_Identity&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;(144233, 41)
# </br> train&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;(590540, 434)
# </br>
# </br>test_Transaction&nbsp;&nbsp;(506691, 393)
# </br>test_Identity&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;(141907, 41)
# </br> test

# %% [markdown]
# # Train_Tranaction

# %% [markdown]
# >## TransactionDT
# 주어진 시간과의 차이
# </br> train 86400 ~ 15811131
# </br> test 86400 ~ 15811131

# %% [markdown]
# >## TransactionAmt
# 거래 금액
# </br>train 0.251USD ~ 31937.391USD
# </br>test 0.251USD ~ 31937.391USD

# %% [markdown]
# >## ProductCD
# 각 거래별 제품 코드  </BR>'W', 'H', 'C', 'S', 'R'

# %% [markdown]
# >## card1 ~ card6
# 결제카드 정보(카드타입, 카드 카테고리, 발급 은행(issue bank), 도시 등)

# %% [markdown]
# >>**card1(train)** :  1000 ~ 18396 ![card1.png](attachment:card1.png)

# %% [markdown]
# >>**card1(test)** : train 1000 ~ 18396 ![card1%28test%29.PNG](attachment:card1%28test%29.PNG)

# %% [markdown]
# >></br>**card2(train)** : 100 ~ 600 ![card2.PNG](attachment:card2.PNG)

# %% [markdown]
# >></br>**card2(test)** : 100 ~ 600 ![card2%28test%29.PNG](attachment:card2%28test%29.PNG)

# %% [markdown]
# >></br>**card3(train)** : 100 ~ 231  ![card3.PNG](attachment:card3.PNG)

# %% [markdown]
# >></br>**card3(test)** : 100 ~ 232 ![card3%28test%29.PNG](attachment:card3%28test%29.PNG)

# %% [markdown]
# >></br>**card4(train)** : 발급 은행(issue bank)
# >></br>'discover'(미국 신용카드 회사), 'mastercard', 'visa', 'american express', nan
# ![card4.PNG](attachment:card4.PNG)

# %% [markdown]
# >></br>**card4(test)** : 발급 은행(issue bank)
# >></br>'discover'(미국 신용카드 회사), 'mastercard', 'visa', 'american express', nan
# ![card4%28test%29.PNG](attachment:card4%28test%29.PNG)

# %% [markdown]
# >></br>**card5(train)** : 100 ~ 237
# ![card5.PNG](attachment:card5.PNG)

# %% [markdown]
# >></br>**card5(test)** : 100 ~ 237
# ![card5%28test%29.PNG](attachment:card5%28test%29.PNG)

# %% [markdown]
# >></br>**card6(train)** : 카드 타입
# >></br>'credit'(신용), 'debit'(직불), 'debit or credit', 'charge card'(충전카드_월말에 쓴 금액 전액 상환), nan
# ![card6.PNG](attachment:card6.PNG)

# %% [markdown]
# >></br>**card6(test)** : 카드 타입
# ![card6%28test%29.PNG](attachment:card6%28test%29.PNG)

# %% [markdown]
# >## addr1, addr2
# 주소
# >>**addr1** : 10 ~ 102

# %% [markdown]
# >></br>**addr2** : 100 ~ 540

# %% [markdown]
# >## dist1, dist2
# 거리
# >>**dist1** : 0 ~ 10286

# %% [markdown]
# >></br>**dist2** : 0 ~ 11623

# %% [markdown]
# >## P_emaildomain
# 구매자 메일 총 60개
# </br>
# </br> nan, 'gmail.com', 'outlook.com', 'yahoo.com', 'mail.com',
#        'anonymous.com', 'hotmail.com', 'verizon.net', 'aol.com', 'me.com',
#        'comcast.net', 'optonline.net', 'cox.net', 'charter.net',
#        'rocketmail.com', 'prodigy.net.mx', 'embarqmail.com', 'icloud.com',
#        'live.com.mx', 'gmail', 'live.com', 'att.net', 'juno.com',
#        'ymail.com', 'sbcglobal.net', 'bellsouth.net', 'msn.com', 'q.com',
#        'yahoo.com.mx', 'centurylink.net', 'servicios-ta.com',
#        'earthlink.net', 'hotmail.es', 'cfl.rr.com', 'roadrunner.com',
#        'netzero.net', 'gmx.de', 'suddenlink.net', 'frontiernet.net',
#        'windstream.net', 'frontier.com', 'outlook.es', 'mac.com',
#        'netzero.com', 'aim.com', 'web.de', 'twc.com', 'cableone.net',
#        'yahoo.fr', 'yahoo.de', 'yahoo.es', 'sc.rr.com', 'ptd.net',
#        'live.fr', 'yahoo.co.uk', 'hotmail.fr', 'hotmail.de',
#        'hotmail.co.uk', 'protonmail.com', 'yahoo.co.jp'

# %% [markdown]
# >## R_emaildomain
# 수령자 메일 총 61개
# </br>
# </br> nan, 'gmail.com', 'hotmail.com', 'outlook.com', 'anonymous.com',
#        'charter.net', 'prodigy.net.mx', 'comcast.net', 'live.com.mx',
#        'icloud.com', 'yahoo.com', 'aol.com', 'juno.com', 'att.net',
#        'verizon.net', 'yahoo.com.mx', 'bellsouth.net', 'servicios-ta.com',
#        'ymail.com', 'hotmail.es', 'msn.com', 'optonline.net', 'live.com',
#        'gmx.de', 'aim.com', 'mail.com', 'me.com', 'outlook.es', 'cox.net',
#        'earthlink.net', 'embarqmail.com', 'web.de', 'sbcglobal.net',
#        'scranton.edu', 'mac.com', 'twc.com', 'roadrunner.com', 'yahoo.fr',
#        'yahoo.de', 'yahoo.es', 'frontiernet.net', 'gmail', 'live.fr',
#        'q.com', 'yahoo.co.uk', 'windstream.net', 'suddenlink.net',
#        'hotmail.fr', 'ptd.net', 'hotmail.de', 'frontier.com',
#        'cfl.rr.com', 'hotmail.co.uk', 'netzero.com', 'netzero.net',
#        'yahoo.co.jp', 'rocketmail.com', 'centurylink.net',
#        'protonmail.com', 'cableone.net', 'sc.rr.com'
#         </br></br> 수령자 메일에 존재하는 scranton.edu은 구매자 메일에 없다

# %% [markdown]
# >## C1 ~ C14
# 결제카드와 관련된 주소의 개수
# ![C.PNG](attachment:C.PNG)

# %% [markdown]
# >## D1 ~ D15
# 이전 거래와의 시간 차이

# %% [markdown]
# >## M1 ~ M9
# 카드와 주소의 이름 일치 여부

# %% [markdown]
# >## V1 ~ V399

# %% [markdown]
# # Train_Identity

# %% [markdown]
# >## Device Type
# desktop
# </br>mobile

# %% [markdown]
# >## DeviceInfo
# 1786종

# %% [markdown]
# >## id_12 ~ id_38
#  asdfadf
