# %% [markdown]
# # 크롤링 테스트

# %%
# 라이브러리 import
import os
import pandas as pd
import numpy as np
import math 

# 셀레늄
from selenium.webdriver.common.alert import Alert
from selenium import webdriver  # 라이브러리(모듈) 가져오라
# pip install chromedriver_autoinstaller
from selenium.webdriver.common.keys import Keys
from selenium.webdriver import ActionChains as AC

# tqdm : for문 진행상황 체크
from tqdm import tqdm, tqdm_notebook
from tqdm.notebook import tqdm

# 정규표현식(regular expression) : 문자(알파벳,한글), 숫자, 특수기호 정제 및 추출
import re
from time import sleep
import time

# 워닝 무시
import warnings
warnings.filterwarnings('ignore')

# %%
# 검색어 입력
search = '삼성전자'

# 크롬 옵션
options = webdriver.ChromeOptions()

# 크롬 윈도우 사이즈 조절
options.add_argument("--window-size=800,1200") # window-size -> 기본 : 1920,1080

import chromedriver_autoinstaller

chrome_path = chromedriver_autoinstaller.install()
driver = webdriver.Chrome(chrome_path, options=options)
time.sleep(0.1)
driver.get("https://www.naver.com")
# -> 네이버 크롬 창이 뜬다.

# %%
# 네이버 검색어 입력 후 검색
element = driver.find_element("name", "query") 
element.clear()  # 혹시 검색창에 존재하는 텍스트 제거

element.send_keys(search)  # 검색창에 검색어 전달
element.submit()  # 검색 클릭
time.sleep(1)

# %%
# 뉴스 클릭
driver.find_element("link text", "뉴스").click() 
time.sleep(1)

# %%
# '오래된 순' 클릭
driver.find_element("link text", "오래된순").click()  
time.sleep(1)

# %%
# news list
news_list = []

newses = driver.find_elements('css selector', 'a.info.press')
temp_list = []
for news in newses:
    temp_list.append(news.text)
    temp_list = [x for x in temp_list ]
news_list = news_list + temp_list 
news_list

# %%
# date list
date_list = []

dates = driver.find_elements('css selector', 'span.info')
temp_list = []
for date in dates:
    temp_list.append(date.text)
    temp_list = [x for x in temp_list ]
date_list = date_list + temp_list 
date_list

# %%
# title list
title_list = []

titles = driver.find_elements('css selector', 'a.news_tit')
temp_list = []
for title in titles:
    temp_list.append(title.text)
    temp_list = [x for x in temp_list ]
title_list = title_list + temp_list 
title_list

# %% [markdown]
# # for문으로 크롤링

# %%
# 검색어 입력
search = '삼성전자'

# 크롬 옵션
options = webdriver.ChromeOptions()

# 크롬 윈도우 사이즈 조절
options.add_argument("--window-size=1000,1200") # window-size -> 기본 : 1920,1080

import chromedriver_autoinstaller

chrome_path = chromedriver_autoinstaller.install()
driver = webdriver.Chrome(chrome_path, options=options)
time.sleep(0.01)
driver.get("https://www.naver.com") # -> 네이버 크롬 창이 뜬다.

# 네이버 검색어 입력 후 검색
element = driver.find_element("name", "query") 
element.clear()  # 혹시 검색창에 존재하는 텍스트 제거

element.send_keys(search)  # 검색창에 검색어 전달
element.submit()  # 검색 클릭
time.sleep(0.01)

# %%
# 뉴스 클릭
driver.find_element("link text", "뉴스").click() 
time.sleep(0.01)

# %%
# '오래된 순' 클릭
driver.find_element("link text", "오래된순").click()  
time.sleep(0.01)

# %%
# 뉴스 데이터 수집
# news_list = []
# date_list = []
# title_list = []

for i in range(200):    

    # 언론사
    newses = driver.find_elements('css selector', 'a.info.press')
    temp_list = []
    for news in newses:
        temp_list.append(news.text)
        temp_list = [x for x in temp_list ]
    news_list = news_list + temp_list 
    
    # 날짜
    dates = driver.find_elements('css selector', 'span.info')
    temp_list = []
    for date in dates:
        temp_list.append(date.text)
        temp_list = [x for x in temp_list ]
    date_list = date_list + temp_list 
    
    # 제목
    titles = driver.find_elements('css selector', 'a.news_tit')
    temp_list = []
    for title in titles:
        temp_list.append(title.text)
        temp_list = [x for x in temp_list ]
    title_list = title_list + temp_list 
    
    # 필모 다음페이지 클릭
    driver.find_element('css selector', 'a.btn_next').click()
    time.sleep(0.01)

print(len(title_list))
print(news_list)
print(date_list)
print(title_list)
# Out:
# 34000
# ['한국경제', '한국경제', '한국경제', '연합뉴스', '머니투데이', '연합뉴스', '머니투데이', '매일경제', '머니투데이', '머니투데이', '머니투데이', '머니투데이', '머니투데이', '머니투데이', '매일경제', '머니투데이', '머니투데이', '머니투데이', '머니투데이', '머니투데이', '국민일보', '국민일보', '국민일보', '머니투데이', '매일경제', '연합뉴스', '머니투데이', '머니투데이', '머니투데이', '매일경제', '매일경제', '매일경제', '연합뉴스', '머니투데이', '연합뉴스', '머니투데이', '머니투데이', '연합뉴스', '매일경제', '매일경제', '매일경제', '매일경제', '머니투데이', '매일경제', '머니투데이', '매일경제', '매일경제', '매일경제', '매일경제', '매일경제', '머니투데이', '매일경제', '매일경제', '머니투데이', '동아일보', '동아일보', '동아일보', '동아일보', '동아일보', '동아일보', '동아일보', '동아일보', '동아일보', '머니투데이', '동아일보', '매일경제', '머니투데이', '머니투데이', '머니투데이', '연합뉴스', '연합뉴스', '매일경제', '머니투데이', '머니투데이', '머니투데이', '머니투데이', '머니투데이', '머니투데이', '머니투데이', '매일경제', '매일경제', '머니투데이', '매일경제', '머니투데이', '머니투데이', '머니투데이', '머니투데이', '머니투데이', '머니투데이', '머니투데이', '머니투데이', '머니투데이', '국민일보', '연합뉴스', '매일경제', '국민일보', '국민일보', '국민일보', '국민일보', '머니투데이', '국민일보', '국민일보', '머니투데이', '머니투데이', '매일경제', '매일경제', '머니투데이', '연합뉴스', '연합뉴스', '연합뉴스', '머니투데이', '매일경제', '연합뉴스', '매일경제', '연합뉴스', '매일경제', '매일경제', '연합뉴스', '매일경제', '머니투데이', '매일경제', '머니투데이', '매일경제', '머니투데이', '매일경제', '매일경제', '매일경제', '머니투데이', '동아일보', '매일경제', '매일경제', '매일경제', '매일경제', '매일경제', '매일경제', '매일경제', '동아일보', '동아일보', '한국경제', '한국경제', '머니투데이', '머니투데이', '매일경제', '머니투데이', '머니투데이', '머니투데이', '머니투데이', '머니투데이', '연합뉴스', '머니투데이', '매일경제', '머니투데이', '머니투데이', '국민일보', '국민일보', '국민일보', '머니투데이', '매일경제', '연합뉴스', '머니투데이', '머니투데이', '머니투데이', '매일경제', '매일경제', '머니투데이', '머니투데이', '매일경제', '연합뉴스', '머니투데이', '머니투데이', '매일경제', '연합뉴스', '매일경제', '동아일보', '매일경제', '매일경제', '머니투데이', '매일경제', '매일경제', '매일경제', '매일경제', '머니투데이', '머니투데이', '머니투데이', '매일경제', '동아일보', '연합뉴스', '매일경제', '매일경제', '국민일보', '매일경제', '국민일보', '동아일보', '동아일보', '동아일보', '동아일보', '동아일보', '동아일보', '동아일보', '머니투데이', '머니투데이', '머니투데이', '머니투데이', '머니투데이', '머니투데이', '매일경제', '매일경제', '매일경제', '머니투데이', '연합뉴스', '국민일보', '국민일보', '연합뉴스', '매일경제', '매일경제', '연합뉴스', '매일경제', '머니투데이', '연합뉴스', '매일경제', '매일경제', '머니투데이', '매일경제', '매일경제', '매일경제', '매일경제', '머니투데이', '매일경제', '국민일보', '국민일보', '머니투데이', '매일경제', '매일경제', '동아일보', '동아일보', '머니투데이', '매일경제', '연합뉴스', '머니투데이', '국민일보', '연합뉴스', '머니투데이', '머니투데이', '머니투데이', '머니투데이', '연합뉴스', '한국경제', '한국경제', '한국경제', '한국경제', '한국경제', '한국경제', '한국경제', '한국경제', '한국경제', '한국경제', '머니투데이', '연합뉴스', '연합뉴스', '머니투데이', '매일경제', '머니투데이', '한국경제', '매일경제', '매일경제', '한국경제', '한국경제', '한국경제', '연합뉴스', '동아일보', '매일경제', '매일경제', '동아일보', '연합뉴스', '매일경제', '매일경제', '한국경제', '매일경제', '매일경제', '한국경제', '동아일보', '동아일보', '동아일보', '동아일보', '동아일보', '동아일보', '한국경제', '한국경제', '한국경제', '머니투데이', '매일경제', '한국경제', '매일경제', '매일경제', '한국경제', '머니투데이', '매일경제', '연합뉴스', '머니투데이', '연합뉴스', '국민일보', '한국경제', '머니투데이', '머니투데이', '머니투데이', '머니투데이', '머니투데이', '국민일보', '매일경제', '연합뉴스', '머니투데이', '국민일보', '국민일보', '매일경제', '국민일보', '국민일보', '머니투데이', '머니투데이', '국민일보', '한국경제', '매일경제', '머니투데이', '연합뉴스', '연합뉴스', '한국경제', '머니투데이', '머니투데이', '한국경제', '한국경제', '연합뉴스', '연합뉴스', '연합뉴스', '머니투데이', '매일경제', '매일경제', '매일경제', '매일경제', '매일경제', '한국경제', '한국경제', '한국경제', '매일경제', '매일경제', '매일경제', '한국경제', '한국경제', '한국경제', '동아일보', '한국경제', '매일경제', '매일경제', '한국경제', '연합뉴스', '국민일보', '한국경제', '한국경제', '매일경제', '매일경제', '국민일보', '동아일보', '머니투데이', '동아일보', '동아일보', '동아일보', '한국경제', '머니투데이', '한국경제', '한국경제', '한국경제', '한국경제', '한국경제', '한국경제', '머니투데이', '머니투데이', '머니투데이', '한국경제', '머니투데이', '머니투데이', '매일경제', '연합뉴스', '한국경제', '매일경제', '한국경제', '한국경제', '국민일보', '한국경제', '매일경제', '매일경제', '한국경제', '연합뉴스', '매일경제', '머니투데이', '한국경제', '한국경제', '한국경제', '한국경제', '국민일보', '국민일보', '국민일보', '한국경제', '한국경제', '매일경제', '머니투데이', '한국경제', '머니투데이', '동아일보', '한국경제', '매일경제', '머니투데이', '매일경제', '한국경제', '한국경제', '한국경제', '한국경제', '한국경제', '한국경제', '머니투데이', '매일경제', '한국경제', '매일경제', '한국경제', '한국경제', '매일경제', '한국경제', '한국경제', '한국경제', '한국경제', '한국경제', '매일경제', '동아일보', '매일경제', '머니투데이', '동아일보', '동아일보', '매일경제', '한국경제', '동아일보', '동아일보', '동아일보', '동아일보', '연합뉴스', '연합뉴스', '매일경제', '머니투데이', '매일경제', '매일경제', '매일경제', '매일경제', '매일경제', '국민일보', '머니투데이', '머니투데이', '머니투데이', '매일경제', '머니투데이', '매일경제', '머니투데이', '연합뉴스', '매일경제', '매일경제', '머니투데이', '연합뉴스', '매일경제', '매일경제', '연합뉴스', '매일경제', '매일경제', '매일경제', '머니투데이', '매일경제', '매일경제', '매일경제', '머니투데이', '매일경제', '매일경제', '매일경제', '매일경제', '매일경제', '동아일보', '동아일보', '동아일보', '동아일보', '연합뉴스', '동 ...
# ['2001.10
 관심", '<거래소시황> 종합주가지수 10.99P오른 541.49에 종료(장종료)', '[마감시황] 주가 540선 돌파', '<거래소시황> 외국인 대량매수에 테러후 처음 540선 회복(잠정)', '日 D램업체 반덤핑 제소 영향', '삼성전자 3분기 실적, 외국증권사 긍정적 시각', "<외국인 이달 1조4천억원 `바이코리아'>", '선진국 한국 주력수출품 통상압력 강화', '[선물마감]외인매수..한때 66 돌파', '[거래소시황] 지수 테러이전 수준 회복', '[거래소마감]외인10일 "사자"..540 안착', '뷰익챌린지대회 25일 티오프...최경주.박세리 출전', '[외국인/기관/개인동향] 삼성전자 "외인 80여일만에 최대매수"', '종합주가지수 테러전 수준 회복', '세계 각국 반덤핑 트집 자국산업 보호', '[日 반도체업계, 韓 반덤핑 제소] 日 D램사업 한계 봉착했나', '[코스닥] "DVR 고성장, 아이디스-쓰리알 관심"-미래', '[부음]윤자헌·자영·자길씨 모친상 등', '"한국, 아시아 최고" 주식 매집', "업계 '기술우수' 알리기 총력", 'PC업계 마케팅戰 막올라...윈도XP 한글판 26일 정식발표', '[표] 거래소 외국인 순매수.순매도 상위종목', '[표] 거래소 기관 순매수.순매도 상위종목', '[표] MSCI 편입 상위종목 외국인 매수한도 추정금액', '[표] 주요 수출업종 통상압력 현황', '日 4개 반도체업체 한국에 反덤핑 공세', '[기업]업종전문화만이 살길인가…FT紙-삼성硏 명암 지적', '세계반도체시장 진흙탕싸움 조짐', '[발굴 배당주] 금융비용 절감 .. 이익 큰폭 개선 .. 제일제당', '[거래소] "외인이 삼성전자 사는 2가지 이유"', '[거래소] "외인 매수는 윈도드레싱일 뿐"', '[CEO포커스] 이우희 에스원  ...

# %%
len(date_list)
# Out:
# 34000

# %%
# df로 만들기

df = pd.DataFrame(list(zip(news_list, date_list, title_list)), columns = ['언론사','날짜', '제목'])

df.to_csv('2002.csv')

# %%
df[-50:]
# Out:
#           언론사           날짜                                   제목
# 33950  디지털타임스  2003.01.07.              삼성전자 LCD모니터 포천지 최고제품 선정
# 33951  디지털타임스  2003.01.07.                 MS, CDMA용 휴대폰 OS 선보여
# 33952  디지털타임스  2003.01.07.         반도체장비업체 주가, 낙관적 시장전망으로 강세 기록
# 33953    연합뉴스  2003.01.07.           <인텔.삼성, 올해 2위업체와 격차 더 벌릴듯>
# 33954    연합뉴스  2003.01.07.                메릴린치, 모토로라 실적 전망 상향조정
# 33955     MBN  2003.01.07.                  "삼성흔들기 국내경제 전체 악영향"
# 33956    연합뉴스  2003.01.07.        "삼성전자 4분기 영업익 1.8조~2조원"<대우증권>
# 33957    연합뉴스  2003.01.07.            "올 IT 성장을 이끌 3A 테마"<한투증권>
# 33958    연합뉴스  2003.01.07.             "장기 상승기업 3.2% 불과"<굿모닝신한>
# 33959   머니투데이  2003.01.07.                      [개장전]외인시대(外人時代)
# 33960     MBN  2003.01.07.                            반도체 안정 성장
# 33961    전자신문  2003.01.07.                                   시황
# 33962    전자신문  2003.01.07.    유비쿼터스 컴퓨팅 '말로만' 핵심인프라 IPv6 '나몰라라'
