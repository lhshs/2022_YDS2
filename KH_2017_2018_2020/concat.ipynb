# %%
import pandas as pd

# %%
df2018_1 = pd.read_csv('/Users/lhs2/Desktop/GitHub/NLP_pjt/KH_2017_2018_2020/2018-07-12.csv', index_col = 0)
df2018_2 = pd.read_csv('/Users/lhs2/Desktop/GitHub/NLP_pjt/KH_2017_2018_2020/2018-11-23.csv', index_col = 0)
df2018_3 = pd.read_csv('/Users/lhs2/Desktop/GitHub/NLP_pjt/KH_2017_2018_2020/2018-12-20.csv', index_col = 0)

df2019_1 = pd.read_csv('/Users/lhs2/Desktop/GitHub/NLP_pjt/KH_2017_2018_2020/2019-01-29.csv', index_col = 0)
df2019_2 = pd.read_csv('/Users/lhs2/Desktop/GitHub/NLP_pjt/KH_2017_2018_2020/2019-03-17~2020-09-17.csv', index_col = 0)
df2019_3 = pd.read_csv('/Users/lhs2/Desktop/GitHub/NLP_pjt/KH_2017_2018_2020/2019-03-27.csv', index_col = 0)

df2020_1 = pd.read_csv('/Users/lhs2/Desktop/GitHub/NLP_pjt/KH_2017_2018_2020/2020-02-19.csv', index_col = 0)
df2020_2 = pd.read_csv('/Users/lhs2/Desktop/GitHub/NLP_pjt/KH_2017_2018_2020/2020-02-19~2021.07.07.csv', index_col = 0)

# %%
df_2018 = pd.concat([df2018_1, df2018_2, df2018_3])
df_2019 = pd.concat([df2019_1, df2019_3, df2019_2])
df_2020 = pd.concat([df2020_1, df2020_2])

# %%
df_2018
# Out:
#           언론사           날짜                              제목
# 0        매일경제     A23면 TOP             동원산업·휠라코리아 "생큐 트럼프"
# 1        매일경제  2018.01.01.           매경춘추 새 필진과 새해 아침을 여세요
# 2        매일경제  2018.01.01.          스마트베타ETF 고공행진 새해도 이어질까
# 3      스카이데일리      A23면 3단     2018 무술년…한국금융 헤게모니 쥔 개띠 거물들
# 4        국제신문  2018.01.01.  “2018년, 과거 바로잡고 국민의 삶 바꾸는데 집중”
# ...       ...          ...                             ...
# 18987  한국금융신문  2018.12.20.           [데스크칼럼] 한국 경제에 겨울이 온다
# 18988    한국경제       20면 1단                        中화웨이의 반격
# 18989    한국경제  2018.12.20.    코스피 상장사 배당금 총액 사상 첫 30조 돌파할듯
# 18990    한국경제  2018.12.20.     SKT·LGU+ "CES서 5G 성장동력 찾는다"
# 18991    한국경제  2018.12.20.      삼성 "영화 볼 동안 에어드레서에 옷 맡기세요"
#
# [265674 rows x 3 columns]

# %%
df_2019
# Out:
#                언론사           날짜  \
# 0             전자신문      30면 TOP
# 1             서울경제  2018.12.20.
# 2             서울경제  2018.12.20.
# 3             매일경제  2018.12.20.
# 4             부산일보      A39면 1단
# ...            ...          ...
# 455938         뉴스핌  2020.09.17.
# 455939  한국경제언론사 선정      14면 TOP
# 455940         YTN  2020.09.17.
# 455941        아주경제       14면 1단
# 455942      아시아타임즈  2020.09.17.
#
#                                                        제목
# 0                                    ?[2018 하반기 인기상품]품질우수
# 1              "가족장으로 바꿔라"...'고 염호석씨' 부친 회유 전직 경찰 구속영장 기각
# 2                     ‘에버랜드 노조와해 의혹’ 강경훈 삼성전자 부사장 구속영장 기각
# 3                            [CEO 인사이트] 무케시 암바니 회장의 지네 경영
# 4                          "냉장고, 설치장소 온도 따라 소비전력 2배 차이 나"
# ...                                                   ...
# 455938                  고 이건희 회장 빈소 나서는 문성현 경제사회노동위원회 위원장
# 455939                         경주 양성자가속기 빔 이용 경쟁률 '역대 최고'
# ...

# %%
df_2018_2019 = pd.concat([df_2018, df_2019])
df_2018_2019
# Out:
#                언론사           날짜  \
# 0             매일경제     A23면 TOP
# 1             매일경제  2018.01.01.
# 2             매일경제  2018.01.01.
# 3           스카이데일리      A23면 3단
# 4             국제신문  2018.01.01.
# ...            ...          ...
# 455938         뉴스핌  2020.09.17.
# 455939  한국경제언론사 선정      14면 TOP
# 455940         YTN  2020.09.17.
# 455941        아주경제       14면 1단
# 455942      아시아타임즈  2020.09.17.
#
#                                                        제목
# 0                                     동원산업·휠라코리아 "생큐 트럼프"
# 1                                   매경춘추 새 필진과 새해 아침을 여세요
# 2                                  스마트베타ETF 고공행진 새해도 이어질까
# 3                             2018 무술년…한국금융 헤게모니 쥔 개띠 거물들
# 4                          “2018년, 과거 바로잡고 국민의 삶 바꾸는데 집중”
# ...                                                   ...
# 455938                  고 이건희 회장 빈소 나서는 문성현 경제사회노동위원회 위원장
# 455939                         경주 양성자가속기 빔 이용 경쟁률 '역대 최고'
# ...

# %%
df_2018_2019 = df_2018_2019.drop_duplicates()

# %%
df_2018_2019 = df_2018_2019[:550000]
df_2018_2019
# Out:
#            언론사           날짜                                             제목
# 0         매일경제     A23면 TOP                            동원산업·휠라코리아 "생큐 트럼프"
# 1         매일경제  2018.01.01.                          매경춘추 새 필진과 새해 아침을 여세요
# 2         매일경제  2018.01.01.                         스마트베타ETF 고공행진 새해도 이어질까
# 3       스카이데일리      A23면 3단                    2018 무술년…한국금융 헤게모니 쥔 개띠 거물들
# 4         국제신문  2018.01.01.                 “2018년, 과거 바로잡고 국민의 삶 바꾸는데 집중”
# ...        ...          ...                                            ...
# 229629   머니투데이  2020.01.07.                 [양희동의 타임머신]이재용 부회장, 설 명절엔 어디로?
# 229630    전자신문  2020.01.07.         갤럭시 S20, 3월 공개 사양 관심 집중...강력해진 카메라 기능?
# 229631  이코노믹리뷰  2020.01.07.  연예계 ‘해킹 게이트’ 비하인드 | #주진모장동건현빈 #사생활유출 #탑골버닝...
# 229632    이투뉴스  2020.01.07.                 막 내린 '창업 1세대' 시대…3·4세 경영 날개 편다
# 229633   에너지경제  2020.01.07.             [증권상품 풍향계] 삼성전자 상승세에 관련 펀드 등장 '주목'
#
# [550000 rows x 3 columns]

# %%
df_2018_2019 = df_2018_2019.to_csv('2018_2019.csv')

# %%
# df_2018_2019 = df_2018.reset_index().drop(columns=['index'])
# df_2018
# Out:
#                언론사           날짜  \
# 0             매일경제     A23면 TOP
# 1             매일경제  2018.01.01.
# 2             매일경제  2018.01.01.
# 3           스카이데일리      A23면 3단
# 4             국제신문  2018.01.01.
# ...            ...          ...
# 455938         뉴스핌  2020.09.17.
# 455939  한국경제언론사 선정      14면 TOP
# 455940         YTN  2020.09.17.
# 455941        아주경제       14면 1단
# 455942      아시아타임즈  2020.09.17.
#
#                                                        제목
# 0                                     동원산업·휠라코리아 "생큐 트럼프"
# 1                                   매경춘추 새 필진과 새해 아침을 여세요
# 2                                  스마트베타ETF 고공행진 새해도 이어질까
# 3                             2018 무술년…한국금융 헤게모니 쥔 개띠 거물들
# 4                          “2018년, 과거 바로잡고 국민의 삶 바꾸는데 집중”
# ...                                                   ...
# 455938                  고 이건희 회장 빈소 나서는 문성현 경제사회노동위원회 위원장
# 455939                         경주 양성자가속기 빔 이용 경쟁률 '역대 최고'
# ...

# %%
df_2020
# Out:
#            언론사           날짜                                                 제목
# 0        스포츠경향  2020.01.01.                         스마트폰 품질 보증기간, 1년에서 2년으로 연장
# 1        데일리시큐  2020.01.01.     갤럭시S10 5G 20만원대, 아이폰11PRO 등 2020년 새해 특가 '좌표어때'
# 2       한국경제TV  2020.01.01.  폰의달인, 갤럭시S10·아이폰7·LG G8 등 공짜폰 대란…“2020 경자년(庚子年...
# 3         이투뉴스  2020.01.01.                   갤럭시S10+, 아이폰11PRO 등 단가 인하로 구매 적기
# 4        아이티비즈  2020.01.01.             '극딜나라' 아이폰8, 아이폰XS, 아이폰xr 마지막 연말 할인 돌입
# ...        ...          ...                                                ...
# 450197  한국금융신문  2021.07.07.                       '이재용 가석방' 하루 앞두고…삼성전자 첫 단체협약
# 450198    중앙일보  2021.07.07.             '삼성 서비스센터서 칼부림' 40대 남성 구속…범행 동기 '묵묵무답'
# 450199    중앙일보  2021.07.07.              경실련 윤순철, 삼성웰스토리 부당지원 최지성ㆍ정현호 업무상배임 고발
# 450200     YTN  2021.07.07.                               원화값 1160원대…10개월만에 최저
# 450201     KBS      A19면 1단                          이재용 가석방, '박근혜 사면'으로 이어질까?
#
# ...

# %%
df_2020 = df_2020.drop_duplicates().reset_index()

# %%
df_2020 = df_2020.reset_index().drop(columns=['index'])
df_2020
# Out:
#         level_0     언론사           날짜  \
# 0             0   스포츠경향  2020.01.01.
# 1             1   데일리시큐  2020.01.01.
# 2             2  한국경제TV  2020.01.01.
# 3             3    이투뉴스  2020.01.01.
# 4             4   아이티비즈  2020.01.01.
# ...         ...     ...          ...
# 483844   483844  한국금융신문  2021.07.07.
# 483845   483845    중앙일보  2021.07.07.
# 483846   483846    중앙일보  2021.07.07.
# 483847   483847     YTN  2021.07.07.
# 483848   483848     KBS      A19면 1단
#
#                                                        제목
# 0                              스마트폰 품질 보증기간, 1년에서 2년으로 연장
# 1          갤럭시S10 5G 20만원대, 아이폰11PRO 등 2020년 새해 특가 '좌표어때'
# 2       폰의달인, 갤럭시S10·아이폰7·LG G8 등 공짜폰 대란…“2020 경자년(庚子年...
# 3                        갤럭시S10+, 아이폰11PRO 등 단가 인하로 구매 적기
# 4                  '극딜나라' 아이폰8, 아이폰XS, 아이폰xr 마지막 연말 할인 돌입
# ...                                                   ...
# 483844                       '이재용 가석방' 하루 앞두고…삼성전자 첫 단체협약
# ...

# %%
df_2020 = df_2020[:335000]
df_2020
# Out:
#         level_0     언론사           날짜  \
# 0             0   스포츠경향  2020.01.01.
# 1             1   데일리시큐  2020.01.01.
# 2             2  한국경제TV  2020.01.01.
# 3             3    이투뉴스  2020.01.01.
# 4             4   아이티비즈  2020.01.01.
# ...         ...     ...          ...
# 334995   334995     더구루  2021.01.18.
# 334996   334996    연합뉴스  2021.01.18.
# 334997   334997    미디어펜  2021.01.18.
# 334998   334998  아시아투데이  2021.01.18.
# 334999   334999    연합뉴스  2021.01.18.
#
#                                                        제목
# 0                              스마트폰 품질 보증기간, 1년에서 2년으로 연장
# 1          갤럭시S10 5G 20만원대, 아이폰11PRO 등 2020년 새해 특가 '좌표어때'
# 2       폰의달인, 갤럭시S10·아이폰7·LG G8 등 공짜폰 대란…“2020 경자년(庚子年...
# 3                        갤럭시S10+, 아이폰11PRO 등 단가 인하로 구매 적기
# 4                  '극딜나라' 아이폰8, 아이폰XS, 아이폰xr 마지막 연말 할인 돌입
# ...                                                   ...
# 334995                           쿠팡, 백수하 커뮤니케이션 담당 부사장 영입
# ...

# %%
df_2020.to_csv('2020.csv')
