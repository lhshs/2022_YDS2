# %% [markdown]
# # TRAIN (3805, 6)

# %% [markdown]
# ## Columns

# %% [markdown]
# 'id', 'age', 'gender', 'respiratory_condition', 'fever_or_muscle_pain', 'covid19'

# %% [markdown]
# ## 확진자 비율

# %% [markdown]
# ![%E1%84%83%E1%85%A1%E1%84%8B%E1%85%AE%E1%86%AB%E1%84%85%E1%85%A9%E1%84%83%E1%85%B3.png](attachment:%E1%84%83%E1%85%A1%E1%84%8B%E1%85%AE%E1%86%AB%E1%84%85%E1%85%A9%E1%84%83%E1%85%B3.png)

# %% [markdown]
# over or under sampling 이 필요해 보인다

# %% [markdown]
# ![%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202022-06-24%20%E1%84%8B%E1%85%A9%E1%84%92%E1%85%AE%207.11.06.png](attachment:%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202022-06-24%20%E1%84%8B%E1%85%A9%E1%84%92%E1%85%AE%207.11.06.png)

# %% [markdown]
# ![%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202022-06-24%20%E1%84%8B%E1%85%A9%E1%84%92%E1%85%AE%207.11.18.png](attachment:%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202022-06-24%20%E1%84%8B%E1%85%A9%E1%84%92%E1%85%AE%207.11.18.png)

# %% [markdown]
# ![%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202022-06-24%20%E1%84%8B%E1%85%A9%E1%84%92%E1%85%AE%207.11.25.png](attachment:%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202022-06-24%20%E1%84%8B%E1%85%A9%E1%84%92%E1%85%AE%207.11.25.png)

# %% [markdown]
# ![%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202022-06-24%20%E1%84%8B%E1%85%A9%E1%84%92%E1%85%AE%207.11.31.png](attachment:%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202022-06-24%20%E1%84%8B%E1%85%A9%E1%84%92%E1%85%AE%207.11.31.png)

# %% [markdown]
# ![%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202022-06-24%20%E1%84%8B%E1%85%A9%E1%84%92%E1%85%AE%207.11.36.png](attachment:%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202022-06-24%20%E1%84%8B%E1%85%A9%E1%84%92%E1%85%AE%207.11.36.png)

# %% [markdown]
# # TEST (5732, 5)

# %% [markdown]
# ## Columns

# %% [markdown]
# 'id', 'age', 'gender', 'respiratory_condition', 'fever_or_muscle_pain'

# %% [markdown]
# ![%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202022-06-24%20%E1%84%8B%E1%85%A9%E1%84%92%E1%85%AE%207.11.44.png](attachment:%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202022-06-24%20%E1%84%8B%E1%85%A9%E1%84%92%E1%85%AE%207.11.44.png)

# %% [markdown]
# ![%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202022-06-24%20%E1%84%8B%E1%85%A9%E1%84%92%E1%85%AE%207.11.50.png](attachment:%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202022-06-24%20%E1%84%8B%E1%85%A9%E1%84%92%E1%85%AE%207.11.50.png)

# %% [markdown]
# ![%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202022-06-24%20%E1%84%8B%E1%85%A9%E1%84%92%E1%85%AE%207.11.57.png](attachment:%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202022-06-24%20%E1%84%8B%E1%85%A9%E1%84%92%E1%85%AE%207.11.57.png)

# %% [markdown]
# ![%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202022-06-24%20%E1%84%8B%E1%85%A9%E1%84%92%E1%85%AE%207.12.15.png](attachment:%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202022-06-24%20%E1%84%8B%E1%85%A9%E1%84%92%E1%85%AE%207.12.15.png)
