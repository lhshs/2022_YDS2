# %%
import pandas as pd
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# %%
kospi = pd.read_csv('data/CJ.csv')

# %%
df2 = pd.read_excel('kosis_data/raw/경기종합지수_2015100__구성지표_시계열__10차__20221019164124.xlsx')
df3 = pd.read_excel('kosis_data/raw/경제심리지수_20221019164010.xlsx')

df4 = pd.read_excel('kosis_data/raw/국내공급물가지수_20221019165826.xlsx')
df5 = pd.read_excel('kosis_data/raw/국내공급물가지수_20221019165900.xlsx')

df6 = pd.read_excel('kosis_data/raw/소비자물가지수_2020100__20221019165439.xlsx')

df7 = pd.read_excel('kosis_data/raw/수입물가지수_기본분류__20221019170456.xlsx')
df8 = pd.read_excel('kosis_data/raw/수입물가지수_기본분류__20221019170558.xlsx')
df9 = pd.read_excel('kosis_data/raw/수입물가지수_기본분류__20221019170655.xlsx')
df10 = pd.read_excel('kosis_data/raw/수입물가지수_기본분류__20221019170803.xlsx')

df11 = pd.read_excel('kosis_data/raw/수출물가지수_기본분류__20221019171403.xlsx')
df12 = pd.read_excel('kosis_data/raw/수출물가지수_기본분류__20221019171242.xlsx')
df13 = pd.read_excel('kosis_data/raw/수출물가지수_기본분류__20221019171321.xlsx')
df14 = pd.read_excel('kosis_data/raw/수출물가지수_기본분류__20221019171053.xlsx')

df15 = pd.read_excel('kosis_data/raw/식료품_및_에너지제외지수_2020100__20221019165651.xlsx')

df18 = pd.read_excel('kosis_data/raw/주유소_평균_판매가격_20221019170002.xlsx')

# %%
df66 = pd.read_csv('kosis_data/수출물가지수.csv')

# %%
a = to_csv(df66).sort_index(ascending=True)

# %%
a = a.drop(a.index[-])
a
# Out:
#                     0                    1                       2    \
# 2000.01          133.65                86.79                   86.79
# 2000.02          130.63                83.04                   83.04
# 2000.03           129.6                77.49                   77.49
# 2000.04          129.07                77.34                   77.34
# 2000.05          128.96                75.79                   75.79
# ...                 ...                  ...                     ...
# 2022.06          117.43               124.33                  124.33
# 2022.07          111.91               122.36                  122.36
# 2022.08          109.49               121.22                  121.22
# 2022.09          107.09               118.55                  118.55
# 계정코드별    총지수 (2015=100)  　　　농림수산품 (2015=100)  　　　　　　농림수산품 (2015=100)
#
#                              3                             4    \
# 2000.01                    89.12                         89.12
# ...

# %%
a
# Out:
#                     0                    1                       2    \
# 2000.01          133.65                86.79                   86.79
# 2000.02          130.63                83.04                   83.04
# 2000.03           129.6                77.49                   77.49
# 2000.04          129.07                77.34                   77.34
# 2000.05          128.96                75.79                   75.79
# ...                 ...                  ...                     ...
# 2022.06          117.43               124.33                  124.33
# 2022.07          111.91               122.36                  122.36
# 2022.08          109.49               121.22                  121.22
# 2022.09          107.09               118.55                  118.55
# 계정코드별    총지수 (2015=100)  　　　농림수산품 (2015=100)  　　　　　　농림수산품 (2015=100)
#
#                              3                             4    \
# 2000.01                    89.12                         89.12
# ...

# %%
a.rename(columns=a.iloc[-1]).drop(a.index[-1]).to_csv('수출물가지수.csv')

# %%
to_csv(df66)
# Out:
#                     0                    1                       2    \
# 계정코드별    총지수 (2015=100)  　　　농림수산품 (2015=100)  　　　　　　농림수산품 (2015=100)
# 2016.01           91.57                 99.7                    99.7
# 2016.02           91.11                99.49                   99.49
# 2016.03           92.22               104.97                  104.97
# 2016.04           92.69               107.13                  107.13
# ...                 ...                  ...                     ...
# 2004.08          121.24                95.67                   95.67
# 2004.09           122.4                91.92                   91.92
# 2004.10          124.54                95.01                   95.01
# 2004.11           124.9                91.48                   91.48
# 2004.12          122.26                81.19                   81.19
#
#                              3                             4    \
# 계정코드별    　　　　　　　　　농산물 (2015=100)  　　　　　　　　　　　　채소및과실 (2015=100)
# ...

# %%
df2
# Out:
#                                지수별 2000.01 2000.02 2000.03 2000.04 2000.05  \
# 0                 선행종합지수(2015=100)    58.5    58.7      59    58.8    58.8
# 1                   　　　 재고순환지표(%p)       -       -       -       -       -
# 2                       　　　 경제심리지수       -       -       -       -       -
# 3    　　　 기계류내수출하지수(선박제외)(2015=100)       -       -       -       -       -
# 4               　　　 건설수주액(실질)(십억원)       -       -       -       -       -
# 5             　　　수출입물가비율(2015=100)       -       -       -       -       -
# 6             　　　코스피(1980.1.4=100)       -       -       -       -       -
# 7                   　　　 장단기금리차(%p)       -       -       -       -       -
# 8                 동행종합지수(2015=100)    52.3    52.6      53    53.5      54
# 9            　　　 광공업생산지수(2015=100)       -       -       -       -       -
# 10  　　　 서비스업생산지수(도소매업제외)(2015=100)       -       -       -       -       -
# ...

# %%
def to_csv(data):
    data = data.transpose()
    data = data.rename(columns=data.iloc[0]).drop(data.index[0])
    return data

# %%
to_csv(df2).to_csv('경기종합지수.csv')

# %%
to_csv(df2)
# Out:
#             선행종합지수(2015=100) 　　　 재고순환지표(%p) 　　　 경제심리지수  \
# 2000.01                 58.5              -          -
# 2000.02                 58.7              -          -
# 2000.03                   59              -          -
# 2000.04                 58.8              -          -
# 2000.05                 58.8              -          -
# ...                      ...            ...        ...
# 2022.04                128.3          -12.5      104.9
# 2022.05                128.8          -12.0      105.3
# 2022.06 p)             129.2          -14.2      105.0
# 2022.07 p)             129.4          -15.4      102.3
# 2022.08 p)             129.5          -16.1       99.9
#
#            　　　 기계류내수출하지수(선박제외)(2015=100) 　　　 건설수주액(실질)(십억원)  \
# 2000.01                                -                  -
# 2000.02                                -                  -
# 2000.03                                -                  -
# ...

# %%
df17
# Out:
#      BSI코드별                업종코드별  2022.01  2022.02  2022.03  2022.04  2022.05  \
# 0    업황실적1)                  전산업       86       85       83       86       86
# 1       NaN               　　　제조업       90       91       84       87       86
# 2       NaN            　　　　　　식료품       82       80       78       78       78
# 3       NaN             　　　　　　음료       78       67       73       86       90
# 4       NaN             　　　　　　섬유       64       73       62       72       64
# ..      ...                  ...      ...      ...      ...      ...      ...
# 525     NaN           　　　　　　부동산업       87       88       86       79       84
# 526     NaN       　　　　　　전문・과학・기술       82       84       87       84       83
# 527     NaN  　　　　　　사업시설・사업지원・임대업       82       81       79       78       79
# 528     NaN      　　　　　　예술・스포츠・여가       74       78       76       63       68
# 529     NaN           　　　　　　서비스업       86       85       83       82       84
#
# ...

# %%
df15
# Out:
#       식료품 및 에너지제외 2000.01 2000.02 2000.03 2000.04 2000.05 2000.06 2000.07  \
# 0             총지수  62.456  62.647  62.962  62.709  62.393  62.709  62.962
# 1  식료품 및 에너지제외 지수  64.697  64.828  65.286  65.352  65.156  65.221  65.483
# 2       식료품 및 에너지       -       -       -       -       -       -       -
#
#   2000.08 2000.09  ... 2021.12 2022.01 2022.02 2022.03 2022.04 2022.05  \
# 0  63.277  64.098  ...  104.04  104.69  105.30  106.06  106.85  107.56
# 1  65.613   65.94  ...  102.51  103.16  103.59  103.72  104.11  104.60
# 2       -       -  ...  109.39  110.00  111.24  114.22  116.36  117.85
#
#   2022.06 2022.07 2022.08 2022.09
# 0  108.22  108.74  108.62  108.93
# 1  105.04  105.43  105.76  105.71
# 2  119.26  120.23  118.54  120.12
#
# [3 rows x 274 columns]

# %%
to_csv(df18).to_csv('주유소_평균_판매가격.csv')

# %%
kospi = kospi.iloc[:, 1:4]
kospi
# Out:
#             Date  Kospi_Close  Kospi_Change
# 0     2000-01-04     0.195293        0.0301
# 1     2000-01-05     0.183802       -0.0687
# 2     2000-01-06     0.173015       -0.0259
# 3     2000-01-07     0.165013       -0.0126
# 4     2000-01-10     0.177083        0.0407
# ...          ...          ...           ...
# 5619  2022-10-13     0.600067       -0.0180
# 5620  2022-10-14     0.610929        0.0230
# 5621  2022-10-17     0.605290        0.0032
# 5622  2022-10-18     0.620492        0.0136
# 5623  2022-10-19     0.628860        0.0018
#
# [5624 rows x 3 columns]

# %%
plt.figure(figsize=(20, 10))
plt.rcParams['font.family'] = 'NanumGothic'

kospi.Kospi_Close.plot()
# Out:
# <AxesSubplot:>
# findfont: Font family ['NanumGothic'] not found. Falling back to DejaVu Sans.

# %%
df2.to_csv('경기종합지수.csv')

# %%
df6.to_csv('소비자물가지수.csv')

# %%
df6
# Out:
#   시도별  2000.01  2000.02  2000.03  2000.04  2000.05  2000.06  2000.07  2000.08  \
# 0  전국   62.456   62.647   62.962   62.709   62.393   62.709   62.962   63.277
#
#    2000.09  ...  2021.12  2022.01  2022.02  2022.03  2022.04  2022.05  \
# 0   64.098  ...   104.04   104.69    105.3   106.06   106.85   107.56
#
#    2022.06  2022.07  2022.08  2022.09
# 0   108.22   108.74   108.62   108.93
#
# [1 rows x 274 columns]

# %%
df11
# Out:
#                                  계정코드별 통화계약구분코드별  2000.01  2000.02  2000.03  \
# 0                       총지수 (2015=100)      달러기준   133.65   130.63   129.60
# 1                  　　　농림수산품 (2015=100)      달러기준    86.79    83.04    77.49
# 2               　　　　　　농림수산품 (2015=100)      달러기준    86.79    83.04    77.49
# 3              　　　　　　　　　농산물 (2015=100)      달러기준    89.12    89.12    89.12
# 4         　　　　　　　　　　　　채소및과실 (2015=100)      달러기준    89.12    89.12    89.12
# ..                                 ...       ...      ...      ...      ...
# 230          　　　　　　　　　　　　가구 (2015=100)      달러기준    63.53    63.53    63.53
# 231     　　　　　　　　　　　　　　　금속가구 (2015=100)      달러기준     0.00     0.00     0.00
# 232     　　　　　　　　　　　　　　　기타가구 (2015=100)      달러기준    60.23    60.23    60.23
# 233     　　　　　　　　　　　　기타제조업제품 (2015=100)      달러기준    78.87    78.78    78.84
# 234  　　　　　　　　　　　　　　　기타제조업제품 (2015=100)      달러기준    78.23    78.23    78.23
#
# ...

# %%
df1314 = pd.merge(df14, df13, on='계정코드별', how='outer')
df1314
# Out:
#                                  계정코드별 통화계약구분코드별_x 2016.01 2016.02 2016.03  \
# 0                       총지수 (2015=100)        달러기준   91.57   91.11   92.22
# 1                  　　　농림수산품 (2015=100)        달러기준    99.7   99.49  104.97
# 2               　　　　　　농림수산품 (2015=100)        달러기준    99.7   99.49  104.97
# 3              　　　　　　　　　농산물 (2015=100)        달러기준   97.35   89.87   94.66
# 4         　　　　　　　　　　　　채소및과실 (2015=100)        달러기준   97.35   89.87   94.66
# ..                                 ...         ...     ...     ...     ...
# 233          　　　　　　　　　　　　가구 (2015=100)        달러기준   98.22   98.22   98.22
# 234     　　　　　　　　　　　　　　　금속가구 (2015=100)        달러기준   96.81   96.81   96.81
# 235     　　　　　　　　　　　　　　　기타가구 (2015=100)        달러기준   99.24   99.24   99.24
# 236     　　　　　　　　　　　　기타제조업제품 (2015=100)        달러기준   97.03   97.03   97.03
# 237  　　　　　　　　　　　　　　　기타제조업제품 (2015=100)        달러기준   97.03   97.03   97.03
#
# ...

# %%
df121314 = pd.merge(df1314, df12, on='계정코드별', how='outer')
df121314 = df121314.drop(columns='통화계약구분코드별')
df121314
# Out:
#                                  계정코드별 통화계약구분코드별_x 2016.01 2016.02 2016.03  \
# 0                       총지수 (2015=100)        달러기준   91.57   91.11   92.22
# 1                  　　　농림수산품 (2015=100)        달러기준    99.7   99.49  104.97
# 2               　　　　　　농림수산품 (2015=100)        달러기준    99.7   99.49  104.97
# 3              　　　　　　　　　농산물 (2015=100)        달러기준   97.35   89.87   94.66
# 4         　　　　　　　　　　　　채소및과실 (2015=100)        달러기준   97.35   89.87   94.66
# ..                                 ...         ...     ...     ...     ...
# 233          　　　　　　　　　　　　가구 (2015=100)        달러기준   98.22   98.22   98.22
# 234     　　　　　　　　　　　　　　　금속가구 (2015=100)        달러기준   96.81   96.81   96.81
# 235     　　　　　　　　　　　　　　　기타가구 (2015=100)        달러기준   99.24   99.24   99.24
# 236     　　　　　　　　　　　　기타제조업제품 (2015=100)        달러기준   97.03   97.03   97.03
# 237  　　　　　　　　　　　　　　　기타제조업제품 (2015=100)        달러기준   97.03   97.03   97.03
#
# ...

# %%
df11121314 = pd.merge(df121314, df11, on='계정코드별', how='outer')
df11121314 = df11121314.drop(columns='통화계약구분코드별_x')
df11121314
# Out:
#                                  계정코드별 2016.01 2016.02 2016.03 2016.04  \
# 0                       총지수 (2015=100)   91.57   91.11   92.22   92.69
# 1                  　　　농림수산품 (2015=100)    99.7   99.49  104.97  107.13
# 2               　　　　　　농림수산품 (2015=100)    99.7   99.49  104.97  107.13
# 3              　　　　　　　　　농산물 (2015=100)   97.35   89.87   94.66   95.81
# 4         　　　　　　　　　　　　채소및과실 (2015=100)   97.35   89.87   94.66   95.81
# ..                                 ...     ...     ...     ...     ...
# 233          　　　　　　　　　　　　가구 (2015=100)   98.22   98.22   98.22   98.22
# 234     　　　　　　　　　　　　　　　금속가구 (2015=100)   96.81   96.81   96.81   96.81
# 235     　　　　　　　　　　　　　　　기타가구 (2015=100)   99.24   99.24   99.24   99.24
# 236     　　　　　　　　　　　　기타제조업제품 (2015=100)   97.03   97.03   97.03   97.03
# 237  　　　　　　　　　　　　　　　기타제조업제품 (2015=100)   97.03   97.03   97.03   97.03
#
#     2016.05 2016.06 2016.07 2016.08 2016.09  ... 2004.03 2004.04 2004.05  \
# ...

# %%
df11121314.to_csv('수출물가지수.csv')

# %%
df78910 = df78910.transpose()
df78910 = df78910.rename(columns=df78910.iloc[0]).drop(df78910.index[0])
df78910.to_csv()
# Out:
#         총지수 (2015=100) 　　　농림수산품 (2015=100) 　　　　　　농림수산품 (2015=100)  \
# 2000.01          75.47               54.03                  54.03
# 2000.02          75.94               54.09                  54.09
# 2000.03          76.67               54.29                  54.29
# 2000.04          75.17               54.07                  54.07
# 2000.05          76.08               54.57                  54.57
# ...                ...                 ...                    ...
# 2022.05         137.03              130.79                 130.79
# 2022.06          137.0               128.3                  128.3
# 2022.07         130.33              123.08                 123.08
# 2022.08          128.1              122.19                 122.19
# 2022.09         125.36              120.84                 120.84
#
#         　　　　　　　　　농산물 (2015=100) 　　　　　　　　　　　　곡물및식량작물 (2015=100)  \
# 2000.01                   48.62                          45.44
# ...

# %%
df78910.to_csv('수입물가지수.csv')

# %%
df4
# Out:
#                                계정코드별 2010.01 2010.02 2010.03 2010.04 2010.05  \
# 0                     총지수 (2015=100)  100.56  101.07  101.41  102.02   103.5
# 1                  　　　원재료 (2015=100)   116.8  117.43  121.54  123.19  124.34
# 2             　　　　　　원재료국내 (2015=100)    90.4   91.21   92.98   93.06   91.01
# 3             　　　　　　원재료수입 (2015=100)  121.18  121.71  126.19  128.23  130.06
# 4            　　　　　　원재료제조용 (2015=100)  120.93   121.3  124.69  128.45  127.58
# 5     　　　　　　　　　원재료제조용(국내) (2015=100)      89    90.6   92.27   92.64   91.07
# 6     　　　　　　　　　원재료제조용(수입) (2015=100)  126.62  126.66   130.3  134.77  134.03
# 7        　　　　　　원재료건설용(국내) (2015=100)   89.41   89.88   89.88   89.63   89.63
# 8             　　　　　　원재료연료 (2015=100)  100.44  103.89  113.95  101.64  118.87
# 9      　　　　　　　　　원재료연료(국내) (2015=100)   85.91   86.79   86.22   86.08   86.08
# 10     　　　　　　　　　원재료연료(수입) (2015=100)   100.5  104.01  114.07  101.69  119.14
# ...

# %%
df4_5 = pd.merge(df5, df4, on='계정코드별', how='outer')
df4_5
# Out:
#                                계정코드별  2000.01  2000.02  2000.03  2000.04  \
# 0                     총지수 (2015=100)    75.31    75.23    75.14    74.31
# 1                  　　　원재료 (2015=100)    43.95    44.73    44.59    41.80
# 2             　　　　　　원재료국내 (2015=100)    58.16    57.29    56.22    54.63
# 3             　　　　　　원재료수입 (2015=100)    41.23    42.30    42.36    39.37
# 4            　　　　　　원재료제조용 (2015=100)    42.49    43.47    43.40    40.38
# 5     　　　　　　　　　원재료제조용(국내) (2015=100)    54.63    54.08    53.25    52.16
# 6     　　　　　　　　　원재료제조용(수입) (2015=100)    41.10    42.31    42.31    39.11
# 7        　　　　　　원재료건설용(국내) (2015=100)    39.02    39.02    39.02    39.62
# 8             　　　　　　원재료연료 (2015=100)    45.82    45.97    46.36    46.36
# 9      　　　　　　　　　원재료연료(국내) (2015=100)    48.46    48.46    48.46    48.46
# 10     　　　　　　　　　원재료연료(수입) (2015=100)    44.95    45.12    45.59    45.51
# 11            　　　　　　원재료기타 (2015=100)    68.96    66.88    64.96    62.08
# ...

# %%
df4_5 = df4_5.transpose()
df4_5 = df4_5.rename(columns=df4_5.iloc[0]).drop(df4_5.index[0])
df4_5
# Out:
#         총지수 (2015=100) 　　　원재료 (2015=100) 　　　　　　원재료국내 (2015=100)  \
# 2000.01          75.31             43.95                  58.16
# 2000.02          75.23             44.73                  57.29
# 2000.03          75.14             44.59                  56.22
# 2000.04          74.31              41.8                  54.63
# 2000.05          74.56             44.88                  56.28
# ...                ...               ...                    ...
# 2022.04         125.47            189.87                 136.64
# 2022.05         126.75            192.75                  139.3
# 2022.06          127.8            200.87                 139.18
# 2022.07          128.7            209.88                 141.14
# 2022.08         127.39            197.64                 142.51
#
#         　　　　　　원재료수입 (2015=100) 　　　　　　원재료제조용 (2015=100)  \
# 2000.01                  41.23                   42.49
# 2000.02                   42.3                   43.47
# ...

# %%
df4_5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 273 entries, 계정코드별 to 2022.08
# Columns: 117 entries, 0 to 59
# dtypes: object(117)
# memory usage: 251.7+ KB

# %%
df4_5.to_csv('국내공급물가지수.csv')

# %%
df4_5
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/miniforge3/envs/lhs/lib/python3.8/site-packages/IPython/core/formatters.py:707, in PlainTextFormatter.__call__(self, obj)
#     700 stream = StringIO()
#     701 printer = pretty.RepresentationPrinter(stream, self.verbose,
#     702     self.max_width, self.newline,
#     703     max_seq_length=self.max_seq_length,
#     704     singleton_pprinters=self.singleton_printers,
#     705     type_pprinters=self.type_printers,
#     706     deferred_pprinters=self.deferred_printers)
# --> 707 printer.pretty(obj)
#     708 printer.flush()
#     709 return stream.getvalue()
#
# File ~/miniforge3/envs/lhs/lib/python3.8/site-packages/IPython/lib/pretty.py:410, in RepresentationPrinter.pretty(self, obj)
#     407                         return meth(obj, self, cycle)
#     408                 if cls is not object \
# ...
