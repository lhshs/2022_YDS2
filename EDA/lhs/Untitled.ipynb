# %%
import pandas as pd
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# %%
kospi = pd.read_csv('data/CJ.csv')

# %%
df2 = pd.read_excel('kosis_data/경기종합지수_2015100__구성지표_시계열__10차__20221019164124.xlsx')
df3 = pd.read_excel('kosis_data/경제심리지수_20221019164010.xlsx')

df4 = pd.read_excel('kosis_data/국내공급물가지수_20221019165826.xlsx')
df5 = pd.read_excel('kosis_data/국내공급물가지수_20221019165900.xlsx')

df6 = pd.read_excel('kosis_data/소비자물가지수_2020100__20221019165439.xlsx')

df7 = pd.read_excel('kosis_data/수입물가지수_기본분류__20221019170456.xlsx')
df8 = pd.read_excel('kosis_data/수입물가지수_기본분류__20221019170558.xlsx')
df9 = pd.read_excel('kosis_data/수입물가지수_기본분류__20221019170655.xlsx')
df10 = pd.read_excel('kosis_data/수입물가지수_기본분류__20221019170803.xlsx')

df11 = pd.read_excel('kosis_data/수출물가지수_기본분류__20221019171403.xlsx')
df12 = pd.read_excel('kosis_data/수출물가지수_기본분류__20221019171242.xlsx')
df13 = pd.read_excel('kosis_data/수출물가지수_기본분류__20221019171321.xlsx')
df14 = pd.read_excel('kosis_data/수출물가지수_기본분류__20221019171053.xlsx')

df15 = pd.read_excel('kosis_data/식료품_및_에너지제외지수_2020100__20221019165651.xlsx')

df16 = pd.read_excel('kosis_data/업종별_기업경기실사지수__2009.8_실적__20221019164530.xlsx')
df17 = pd.read_excel('kosis_data/업종별_기업경기실사지수__2009.8_실적__20221019164958.xlsx')

df18 = pd.read_excel('kosis_data/주유소_평균_판매가격_20221019170002.xlsx')

# %%
kospi = kospi.iloc[:, 1:4]
kospi
# Out:
#             Date  Kospi_Close  Kospi_Change
# 0     2000-01-04     0.195293        0.0301
# 1     2000-01-05     0.183802       -0.0687
# 2     2000-01-06     0.173015       -0.0259
# 3     2000-01-07     0.165013       -0.0126
# 4     2000-01-10     0.177083        0.0407
# ...          ...          ...           ...
# 5619  2022-10-13     0.600067       -0.0180
# 5620  2022-10-14     0.610929        0.0230
# 5621  2022-10-17     0.605290        0.0032
# 5622  2022-10-18     0.620492        0.0136
# 5623  2022-10-19     0.628860        0.0018
#
# [5624 rows x 3 columns]

# %%
plt.figure(figsize=(20, 10))
plt.rcParams['font.family'] = 'NanumGothic'

kospi.Kospi_Close.plot()
# Out:
# <AxesSubplot:>
# findfont: Font family ['NanumGothic'] not found. Falling back to DejaVu Sans.

# %%
# df3 = df3.transpose()
df3 = df3.rename(columns=df3.iloc[0]).drop(df3.index[0])
df3
# Out:
#         경제심리지수(원계열) 경제심리지수(순환변동치)
# 2003.01       101.0          95.8
# 2003.02       102.2          95.7
# 2003.03        92.4          95.7
# 2003.04          98            96
# 2003.05        96.2          96.5
# ...             ...           ...
# 2022.05       106.7         102.6
# 2022.06       102.5         101.8
# 2022.07        97.8         101.0
# 2022.08        99.3         100.2
# 2022.09        98.0          99.3
#
# [237 rows x 2 columns]

# %%
df4_5 = pd.concat([df5, df4])
df4_5 = df4_5.transpose()
df4_5
# Out:
#                      0                  1                       2   \
# 계정코드별    총지수 (2015=100)  　　　원재료 (2015=100)  　　　　　　원재료국내 (2015=100)
# 2000.01           75.31              43.95                   58.16
# 2000.02           75.23              44.73                   57.29
# 2000.03           75.14              44.59                   56.22
# 2000.04           74.31               41.8                   54.63
# ...                 ...                ...                     ...
# 2022.04             NaN                NaN                     NaN
# 2022.05             NaN                NaN                     NaN
# 2022.06             NaN                NaN                     NaN
# 2022.07             NaN                NaN                     NaN
# 2022.08             NaN                NaN                     NaN
#
#                              3                        4   \
# 계정코드별    　　　　　　원재료수입 (2015=100)  　　　　　　원재료제조용 (2015=100)
# ...

# %%
df4_5 = df4_5.rename(columns=df4_5.iloc[0]).drop(df4_5.index[0])
df4_5
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/miniforge3/envs/lhs/lib/python3.8/site-packages/IPython/core/formatters.py:707, in PlainTextFormatter.__call__(self, obj)
#     700 stream = StringIO()
#     701 printer = pretty.RepresentationPrinter(stream, self.verbose,
#     702     self.max_width, self.newline,
#     703     max_seq_length=self.max_seq_length,
#     704     singleton_pprinters=self.singleton_printers,
#     705     type_pprinters=self.type_printers,
#     706     deferred_pprinters=self.deferred_printers)
# --> 707 printer.pretty(obj)
#     708 printer.flush()
#     709 return stream.getvalue()
#
# File ~/miniforge3/envs/lhs/lib/python3.8/site-packages/IPython/lib/pretty.py:410, in RepresentationPrinter.pretty(self, obj)
#     407                         return meth(obj, self, cycle)
#     408                 if cls is not object \
# ...
