# %%
# 데이터분석
import pandas as pd
import numpy as np 

# 시각화
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib import rc 

import os
import warnings
import random

# ML/DL 모델 및 sklearn
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, roc_auc_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

# 경고 끄기
warnings.filterwarnings(action='ignore')

# 데이터프레임 제한 풀기
# pd.set_option('display.max_row', 100)
# pd.set_option('display.max_columns', 150)
# pd.set_option('display.max_seq_items', None)

# %%
# df = pd.read_csv('data/Samil_label.csv').drop(columns=['Unnamed: 0'])

# df1 = pd.read_csv('kosis_data/경기종합지수.csv').rename(columns ={'Unnamed: 0' : 'month'})
# df2 = pd.read_csv('kosis_data/경제심리지수.csv').rename(columns ={'Unnamed: 0' : 'month'})
# df3 = pd.read_csv('kosis_data/국내공급물가지수.csv').rename(columns ={'Unnamed: 0' : 'month'})
# df4 = pd.read_csv('kosis_data/소비자물가지수.csv').rename(columns ={'Unnamed: 0' : 'month'})
# df5 = pd.read_csv('kosis_data/수입물가지수.csv').rename(columns ={'Unnamed: 0' : 'month'})
# df6 = pd.read_csv('kosis_data/수출물가지수.csv').rename(columns ={'Unnamed: 0' : 'month'})
# df7 = pd.read_csv('kosis_data/식료품_및_에너지제외지수.csv').rename(columns ={'Unnamed: 0' : 'month'})
# df8 = pd.read_csv('kosis_data/주유소_평균_판매가격.csv').rename(columns ={'Unnamed: 0' : 'month'})

samil_df = pd.read_csv('data/Samil_feature_concat.csv').drop(columns=['Unnamed: 0'])

# %%
# 날짜 형식 '-'로 맞추기
def replace_month(data):
    data.month = data.month.astype(str).str.replace('.','-')

# %%
replace_month(df1)
replace_month(df2)
replace_month(df3)
replace_month(df4)
replace_month(df5)
replace_month(df6)
replace_month(df7)
replace_month(df8)

# %%
# 날짜 이상하게 표시된 것 제거
df1.month.iloc[-3:] = df1.month.iloc[-3:].str.replace(' p\)','')

# %%
# 다 합해주기

from functools import reduce

dfs = [df, df1, df2, df3, df4, df5, df6, df7, df8] # df, df1, df4, df5, df6, df7, df8
df_merge = reduce(lambda left, right : pd.merge(left, right, on='month',how='outer'), dfs).sort_values('month')

# %%
# df_merge = df_merge.drop(df_merge.index[-1])

# %%
# df_merge.reset_index().drop(columns=['index']).to_csv('feature.csv')

# %% [markdown]
# ### 전처리

# %%
samil_df
# Out:
#        month  Samil_Close  Samil_Change  Kospi_Close  Kospi_Change  label  \
# 0    2000-01     0.166849      0.466341     0.166989     -0.003865    0.0
# 1    2000-02     0.151669      0.509320     0.150465     -0.006220    0.0
# 2    2000-03     0.283741      0.872881     0.141921      0.002064    0.0
# 3    2000-04     0.305151      0.329995     0.107834     -0.008667    1.0
# 4    2000-05     0.242085      0.337147     0.086009      0.000940    1.0
# ..       ...          ...           ...          ...           ...    ...
# 291  2022-06     0.141677      0.283132     0.704787     -0.006930    0.0
# 292  2022-07     0.122400      0.520008     0.665200      0.002419    1.0
# 293  2022-08     0.139956      0.425427     0.707168      0.000423    0.0
# 294  2022-09     0.113694      0.317581     0.656375     -0.006745    0.0
# 295  2022-10     0.095258      0.476417     0.612482      0.004145    0.0
#
#       선행종합지수(2015=100) 　　　 재고순환지표(%p) 　　　 경제심리지수  \
# 0                 58.5              -          -
# 1                 58.7              -          -
# 2                 59.0              -          -
# 3                 58.8              -          -
# 4                 58.8              -          -
# ..                 ...            ...        ...
# 291              129.2          -14.2      105.0
# 292              129.4          -15.4      102.3
# 293              129.5          -16.1       99.9
# 294                NaN            NaN        NaN
# 295                NaN            NaN        NaN
#
#     　　　 기계류내수출하지수(선박제외)(2015=100)  ... 　　　　　　　　　　　　　　　기타가구 (2015=100)_y  \
# 0                               -  ...                            60.23
# 1                               -  ...                            60.23
# 2                               -  ...                            60.23
# 3                               -  ...                            60.23
# 4                               -  ...                            60.23
# ..                            ...  ...                              ...
# 291                          99.7  ...                           116.86
# 292                         103.0  ...                           116.86
# 293                         105.8  ...                           116.86
# 294                           NaN  ...                           116.86
# 295                           NaN  ...                              NaN
#
#     　　　　　　　　　　　　기타제조업제품 (2015=100)_y 　　　　　　　　　　　　　　　기타제조업제품 (2015=100)  \
# 0                              78.87                             78.23
# 1                              78.78                             78.23
# 2                              78.84                             78.23
# 3                              78.87                             78.23
# 4                              78.81                             78.23
# ..                               ...                               ...
# 291                           109.24                            109.24
# 292                           121.19                            121.19
# 293                           121.19                            121.19
# 294                           121.19                            121.19
# 295                              NaN                               NaN
#
#          총지수  식료품 및 에너지제외 지수 식료품 및 에너지    보통휘발유     실내등유 보일러등유  자동차용 경유
# 0     62.456          64.697         -      NaN      NaN   NaN      NaN
# 1     62.647          64.828         -      NaN      NaN   NaN      NaN
# 2     62.962          65.286         -      NaN      NaN   NaN      NaN
# 3     62.709          65.352         -      NaN      NaN   NaN      NaN
# 4     62.393          65.156         -      NaN      NaN   NaN      NaN
# ..       ...             ...       ...      ...      ...   ...      ...
# 291  108.220         105.040    119.26  2084.00  1601.77     -  2089.03
# 292  108.740         105.430    120.23  2029.99  1686.55     -  2084.91
# 293  108.620         105.760    118.54  1792.19  1639.49     -  1889.31
# 294  108.930         105.710    120.12  1730.00  1620.15     -  1850.20
# 295      NaN             NaN       NaN      NaN      NaN   NaN      NaN
#
# [296 rows x 610 columns]

# %%
# 컬럼 공백 제거
samil_df.columns = samil_df.columns.str.strip()

# %%
# '-' 값 Nan 값으로 변경
samil_df = samil_df.replace('-', np.nan)

# %%
samil_df.info(verbose=True, null_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 296 entries, 0 to 295
# Data columns (total 610 columns):
#  #    Column                         Non-Null Count  Dtype
# ---   ------                         --------------  -----
#  0    month                          296 non-null    object
#  1    Samil_Close                    274 non-null    float64
#  2    Samil_Change                   274 non-null    float64
#  3    Kospi_Close                    274 non-null    float64
#  4    Kospi_Change                   274 non-null    float64
#  5    label                          274 non-null    float64
#  6    선행종합지수(2015=100)               272 non-null    float64
#  7    재고순환지표(%p)                     272 non-null    object
#  8    경제심리지수                         272 non-null    object
#  9    기계류내수출하지수(선박제외)(2015=100)      272 non-null    object
#  10   건설수주액(실질)(십억원)                 272 non-null    object
#  11   수출입물가비율(2015=100)              272 non-null    object
#  12   코스피(1980.1.4=100)              272 non-null    object
#  13   장단기금리차(%p)                     272 non-null    object
#  14   동행종합지수(2015=100)               272 non-null    float64
#  15   광공업생산지수(2015=100)              272 non-null    object
#  16   서비스업생산지수(도소매업제외)(2015=100)     272 non-null    object
#  17   건설기성액(실질)(십억원)                 272 non-null    object
#  18   소매판매액지수(2015=100)              272 non-null    object
#  19   내수출하지수(2015=100)               272 non-null    object
#  20   수입액(실질)(백만불)                   272 non-null    object
#  21   비농림어업취업자수(천명)                  272 non-null    object
#  22   후행종합지수(2015=100)               272 non-null    float64
#  23   생산자제품재고지수(2015=100)            272 non-null    object
#  24   소비자물가지수변화율(서비스)                272 non-null    object
#  25   소비재수입액(실질)(백만불)                272 non-null    object
#  26   취업자수(천명)                       272 non-null    object
#  27   CP유통수익률(%p)                    272 non-null    object
#  28   경제심리지수(원계열)                    237 non-null    float64
#  29   경제심리지수(순환변동치)                  237 non-null    float64
#  30   총지수 (2015=100)_x               272 non-null    float64
#  31   원재료 (2015=100)                 272 non-null    float64
#  32   원재료국내 (2015=100)               272 non-null    float64
#  33   원재료수입 (2015=100)               272 non-null    float64
#  34   원재료제조용 (2015=100)              272 non-null    float64
#  35   원재료제조용(국내) (2015=100)          272 non-null    float64
#  36   원재료제조용(수입) (2015=100)          272 non-null    float64
#  37   원재료건설용(국내) (2015=100)          272 non-null    float64
#  38   원재료연료 (2015=100)               272 non-null    float64
#  39   원재료연료(국내) (2015=100)           272 non-null    float64
#  40   원재료연료(수입) (2015=100)           272 non-null    float64
#  41   원재료기타 (2015=100)               272 non-null    float64
#  42   중간재 (2015=100)                 272 non-null    float64
#  43   중간재국내 (2015=100)               272 non-null    float64
#  44   중간재수입 (2015=100)               272 non-null    float64
#  45   중간재제조용 (2015=100)              272 non-null    float64
#  46   중간재제조용(국내) (2015=100)          272 non-null    float64
#  47   중간재제조용(수입) (2015=100)          272 non-null    float64
#  48   중간재건설용 (2015=100)              272 non-null    float64
#  49   중간재건설용(국내) (2015=100)          272 non-null    float64
#  50   중간재건설용(수입) (2015=100)          272 non-null    float64
#  51   중간재연료・동력 (2015=100)            272 non-null    float64
#  52   중간재연료・동력(국내) (2015=100)        272 non-null    float64
#  53   중간재연료・동력(수입) (2015=100)        272 non-null    float64
#  54   중간재기타 (2015=100)               272 non-null    float64
#  55   중간재기타(국내) (2015=100)           272 non-null    float64
#  56   중간재기타(수입) (2015=100)           272 non-null    float64
#  57   최종재 (2015=100)                 272 non-null    float64
#  58   최종재국내 (2015=100)               272 non-null    float64
#  59   최종재수입 (2015=100)               272 non-null    float64
#  60   최종재자본재 (2015=100)              272 non-null    float64
#  61   최종재자본재(국내) (2015=100)          272 non-null    float64
#  62   최종재자본재(수입) (2015=100)          272 non-null    float64
#  63   최종재소비재 (2015=100)              272 non-null    float64
#  64   최종재소비재(국내) (2015=100)          272 non-null    float64
#  65   최종재소비재(수입) (2015=100)          272 non-null    float64
#  66   최종재내구재 (2015=100)              272 non-null    float64
#  67   최종재내구재(국내) (2015=100)          272 non-null    float64
#  68   최종재내구재(수입) (2015=100)          272 non-null    float64
#  69   최종재비내구재 (2015=100)             272 non-null    float64
#  70   최종재비내구재(국내) (2015=100)         272 non-null    float64
#  71   최종재비내구재(수입) (2015=100)         272 non-null    float64
#  72   생산재(원재료+중간재) (2015=100)        272 non-null    float64
#  73   생산재국내 (2015=100)               272 non-null    float64
#  74   생산재수입 (2015=100)               272 non-null    float64
#  75   생산재제조용재료 (2015=100)            272 non-null    float64
#  76   생산재제조용재료(국내) (2015=100)        272 non-null    float64
#  77   생산재제조용재료(수입) (2015=100)        272 non-null    float64
#  78   생산재건설용재료 (2015=100)            272 non-null    float64
#  79   생산재건설용재료(국내) (2015=100)        272 non-null    float64
#  80   생산재건설용재료(수입) (2015=100)        272 non-null    float64
#  81   생산재연료・동력 (2015=100)            272 non-null    float64
#  82   생산재연료・동력(국내) (2015=100)        272 non-null    float64
#  83   생산재연료・동력(수입) (2015=100)        272 non-null    float64
#  84   생산재기타 (2015=100)               272 non-null    float64
#  85   생산재기타(국내) (2015=100)           272 non-null    float64
#  86   생산재기타(수입) (2015=100)           272 non-null    float64
#  87   원재료기타(국내) (2016.12=100)        152 non-null    object
#  88   원재료기타(수입) (2016.12=100)        152 non-null    object
#  89   최종재서비스 (2015=100)              152 non-null    float64
#  90   전국                             273 non-null    float64
#  91   총지수 (2015=100)_y               273 non-null    float64
#  92   농림수산품 (2015=100)_x             273 non-null    float64
#  93   농림수산품 (2015=100)_x             273 non-null    float64
#  94   농산물 (2015=100)_x               273 non-null    float64
#  95   곡물및식량작물 (2015=100)             273 non-null    float64
#  96   곡류 (2015=100)                  273 non-null    float64
#  97   맥류및잡곡 (2015=100)               273 non-null    float64
#  98   콩류 (2015=100)                  273 non-null    float64
#  99   채소및과실 (2015=100)_x             273 non-null    float64
#  100  과실 (2015=100)_x                273 non-null    float64
#  101  기타작물 (2015=100)                273 non-null    float64
#  102  천연고무 (2015=100)                273 non-null    float64
#  103  기타식용작물 (2015=100)              273 non-null    float64
#  104  기타비식용작물 (2015=100)             273 non-null    float64
#  105  축산물 (2015=100)                 273 non-null    float64
#  106  낙농및육류 (2015=100)               273 non-null    float64
#  107  도축육 (2015=100)                 273 non-null    float64
#  108  임산물 (2015=100)                 273 non-null    float64
#  109  임산물 (2015=100)                 273 non-null    float64
#  110  원목 (2015=100)                  273 non-null    float64
#  111  수산물 (2015=100)_x               273 non-null    float64
#  112  신선수산물 (2015=100)_x             273 non-null    object
#  113  신선어류 (2015=100)_x              273 non-null    object
#  114  냉동건조수산물 (2015=100)_x           273 non-null    float64
#  115  냉동수산물 (2015=100)_x             273 non-null    float64
#  116  광산품 (2015=100)                 273 non-null    float64
#  117  광산품 (2015=100)                 273 non-null    float64
#  118  석탄,원유및천연가스 (2015=100)          273 non-null    float64
#  119  석탄 (2015=100)                  273 non-null    float64
#  120  무연탄 (2015=100)                 273 non-null    object
#  121  유연탄 (2015=100)                 273 non-null    float64
#  122  원유및천연가스 (2015=100)             273 non-null    float64
#  123  원유 (2015=100)                  273 non-null    float64
#  124  천연가스(LNG) (2015=100)           273 non-null    float64
#  125  금속및비금속광물 (2015=100)            273 non-null    float64
#  126  금속광물 (2015=100)                273 non-null    float64
#  127  철광석 (2015=100)                 273 non-null    float64
#  128  기타비철금속광석 (2015=100)            273 non-null    float64
#  129  비금속광물 (2015=100)               273 non-null    float64
#  130  기타비금속광물 (2015=100)             273 non-null    float64
#  131  공산품 (2015=100)_x               273 non-null    float64
#  132  음식료품 (2015=100)_x              273 non-null    float64
#  133  식료품 (2015=100)_x               273 non-null    float64
#  134  육가공품및낙농품 (2015=100)            273 non-null    object
#  135  낙농품 (2015=100)                 273 non-null    object
#  136  수산가공품 (2015=100)_x             273 non-null    float64
#  137  수산물가공품 (2015=100)_x            273 non-null    float64
#  138  제당및전분 (2015=100)_x             273 non-null    float64
#  139  원당 (2015=100)                  273 non-null    float64
#  140  조미료및유지 (2015=100)              273 non-null    float64
#  141  유지 (2015=100)                  273 non-null    float64
#  142  기타식료품 (2015=100)               273 non-null    float64
#  143  과실및채소가공품 (2015=100)            273 non-null    float64
#  144  음료품 (2015=100)                 273 non-null    float64
#  145  주류 (2015=100)                  273 non-null    float64
#  146  기타주류 (2015=100)                273 non-null    float64
#  147  섬유및가죽제품 (2015=100)_x           273 non-null    float64
#  148  섬유및의복 (2015=100)_x             273 non-null    float64
#  149  섬유사 (2015=100)_x               273 non-null    float64
#  150  천연및화학섬유사 (2015=100)_x          273 non-null    float64
#  151  섬유직물 (2015=100)_x              273 non-null    float64
#  152  천연및화학섬유직물 (2015=100)_x         273 non-null    float64
#  153  직물제품 (2015=100)_x              273 non-null    float64
#  154  부직포및펠트 (2015=100)_x            273 non-null    float64
#  155  의복제품 (2015=100)_x              273 non-null    float64
#  156  봉제의류 (2015=100)_x              273 non-null    float64
#  157  편조의류 (2015=100)_x              273 non-null    object
#  158  가죽제품 (2015=100)_x              273 non-null    float64
#  159  가죽제품 (2015=100)_x              273 non-null    float64
#  160  가죽 (2015=100)_x                273 non-null    float64
#  161  가방및핸드백 (2015=100)              273 non-null    object
#  162  신발 (2015=100)_x                273 non-null    float64
#  163  목재및종이제품 (2015=100)_x           273 non-null    float64
#  164  목재및목제품 (2015=100)              273 non-null    float64
#  165  목재 (2015=100)                  273 non-null    float64
#  166  제재목 (2015=100)                 273 non-null    float64
#  167  합판 (2015=100)                  273 non-null    float64
#  168  강화및재생목재 (2015=100)             273 non-null    float64
#  169  펄프및종이제품 (2015=100)_x           273 non-null    float64
#  170  펄프 (2015=100)                  273 non-null    float64
#  171  펄프 (2015=100)                  273 non-null    float64
#  172  종이류 (2015=100)_x               273 non-null    float64
#  173  인쇄용지 (2015=100)_x              273 non-null    float64
#  174  기타원지및판지 (2015=100)             273 non-null    float64
#  175  석탄및석유제품 (2015=100)_x           273 non-null    float64
#  176  석탄및석유제품 (2015=100)_x           273 non-null    float64
#  177  원유정제처리제품 (2015=100)_x          273 non-null    float64
#  178  나프타 (2015=100)_x               273 non-null    float64
#  179  경유 (2015=100)_x                273 non-null    float64
#  180  중유 (2015=100)_x                273 non-null    float64
#  181  액화석유가스 (2015=100)              273 non-null    float64
#  182  화학제품 (2015=100)_x              273 non-null    float64
#  183  기초화학물질 (2015=100)_x            273 non-null    float64
#  184  기초유기화학물질 (2015=100)_x          273 non-null    float64
#  185  지방족기초유분 (2015=100)_x           273 non-null    float64
#  186  방향족기초유분 (2015=100)_x           273 non-null    float64
#  187  석유화학중간제품 (2015=100)_x          273 non-null    float64
#  188  기타기초유기화합물 (2015=100)_x         273 non-null    float64
#  189  기초무기화학물질 (2015=100)            273 non-null    float64
#  190  기초무기화합물 (2015=100)             273 non-null    float64
#  191  염료,안료및유연제 (2015=100)           273 non-null    float64
#  192  합성수지및합성고무 (2015=100)_x         273 non-null    float64
#  193  합성수지및합성고무 (2015=100)_x         273 non-null    float64
#  194  합성수지 (2015=100)_x              273 non-null    float64
#  195  합성고무 (2015=100)_x              273 non-null    float64
#  196  화학섬유 (2015=100)_x              273 non-null    float64
#  197  화학섬유 (2015=100)_x              273 non-null    float64
#  198  화학섬유 (2015=100)_x              273 non-null    float64
#  199  의약품 (2015=100)                 273 non-null    float64
#  200  의약품 (2015=100)                 273 non-null    float64
#  201  의약품 (2015=100)                 273 non-null    float64
#  202  비료및농약 (2015=100)_x             273 non-null    float64
#  203  비료및농약 (2015=100)_x             273 non-null    float64
#  204  비료및질소화합물 (2015=100)_x          273 non-null    float64
#  205  기타화학제품 (2015=100)_x            273 non-null    float64
#  206  도료및잉크 (2015=100)_x             273 non-null    float64
#  207  도료 (2015=100)_x                273 non-null    float64
#  208  비누및화장품 (2015=100)_x            273 non-null    float64
#  209  화장품 (2015=100)_x               273 non-null    float64
#  210  기타화학제품 (2015=100)_x            273 non-null    float64
#  211  접착제및젤라틴 (2015=100)_x           273 non-null    float64
#  212  사진용화학제품및감광재료 (2015=100)        273 non-null    float64
#  213  기타화학제품 (2015=100)_x            273 non-null    float64
#  214  플라스틱제품 (2015=100)_x            273 non-null    float64
#  215  플라스틱1차제품 (2015=100)_x          273 non-null    float64
#  216  플라스틱1차제품 (2015=100)_x          273 non-null    float64
#  217  고무제품 (2015=100)_x              273 non-null    float64
#  218  타이어및튜브 (2015=100)_x            273 non-null    float64
#  219  타이어및튜브 (2015=100)_x            273 non-null    float64
#  220  비금속광물제품 (2015=100)_x           273 non-null    float64
#  221  유리및유리제품 (2015=100)             273 non-null    float64
#  222  유리및유리제품 (2015=100)             273 non-null    float64
#  223  판유리및1차유리제품 (2015=100)          273 non-null    float64
#  224  산업용유리제품(전자기기용제외) (2015=100)    273 non-null    float64
#  225  기타비금속광물제품 (2015=100)_x         273 non-null    float64
#  226  기타비금속광물제품 (2015=100)_x         273 non-null    float64
#  227  석제품 (2015=100)                 273 non-null    float64
#  228  제1차금속제품 (2015=100)_x           273 non-null    float64
#  229  철강1차제품 (2015=100)_x            273 non-null    float64
#  230  선철및조강 (2015=100)_x             273 non-null    float64
#  231  선철 (2015=100)                  273 non-null    float64
#  232  합금철 (2015=100)_x               273 non-null    float64
#  233  조강 (2015=100)_x                273 non-null    float64
#  234  열간압연강재 (2015=100)_x            273 non-null    float64
#  235  철근및봉강 (2015=100)_x             273 non-null    float64
#  236  형강 (2015=100)_x                273 non-null    float64
#  237  중후판(두께3mm이상) (2015=100)_x      273 non-null    float64
#  238  열연강판 (2015=100)_x              273 non-null    float64
#  239  철강관 (2015=100)_x               273 non-null    float64
#  240  냉간압연강재 (2015=100)_x            273 non-null    object
#  241  냉간압연강재 (2015=100)_x            273 non-null    object
#  242  기타철강1차제품 (2015=100)_x          273 non-null    float64
#  243  표면처리강재 (2015=100)_x            273 non-null    float64
#  244  비철금속괴및1차제품 (2015=100)_x        273 non-null    float64
#  245  비철금속괴 (2015=100)_x             273 non-null    float64
#  246  동제련,정련및합금제품 (2015=100)_x       273 non-null    float64
#  247  알루미늄제련,정련및합금제품 (2015=100)      273 non-null    float64
#  248  연및아연제련,정련및합금제품 (2015=100)_x    273 non-null    float64
#  249  금은괴 (2015=100)_x               273 non-null    float64
#  250  기타비철금속제련,정련및합금제품 (2015=100)_x  273 non-null    float64
#  251  비철금속1차제품 (2015=100)_x          273 non-null    float64
#  252  동1차제품 (2015=100)_x             273 non-null    float64
#  253  알루미늄1차제품 (2015=100)_x          273 non-null    float64
#  254  금속가공제품 (2015=100)_x            273 non-null    float64
#  255  금속가공제품 (2015=100)_x            273 non-null    float64
#  256  기타금속가공제품 (2015=100)_x          273 non-null    float64
#  257  공구류 (2015=100)_x               273 non-null    float64
#  258  컴퓨터,전자및광학기기 (2015=100)_x       273 non-null    float64
#  259  반도체 (2015=100)_x               273 non-null    float64
#  260  반도체 (2015=100)_x               273 non-null    float64
#  261  개별소자 (2015=100)_x              273 non-null    float64
#  262  집적회로 (2015=100)_x              273 non-null    float64
#  263  전자표시장치 (2015=100)_x            273 non-null    float64
#  264  전자표시장치 (2015=100)_x            273 non-null    float64
#  265  LCD평판디스플레이 (2015=100)_x        273 non-null    float64
#  266  기타전자부품 (2015=100)_x            273 non-null    float64
#  267  인쇄회로기판 (2015=100)_x            273 non-null    float64
#  268  인쇄회로기판및실장기판 (2015=100)_x       273 non-null    float64
#  269  기타전자부품 (2015=100)_x            273 non-null    float64
#  270  축전기,저항기,전자코일및변성기 (2015=100)_x  273 non-null    float64
#  271  컴퓨터및주변기기 (2015=100)_x          273 non-null    float64
#  272  컴퓨터및주변기기 (2015=100)_x          273 non-null    float64
#  273  컴퓨터 (2015=100)                 273 non-null    float64
#  274  컴퓨터기억장치 (2015=100)_x           273 non-null    float64
#  275  컴퓨터주변기기 (2015=100)_x           273 non-null    float64
#  276  통신,방송및영상,음향기기 (2015=100)_x     273 non-null    float64
#  277  통신및방송장비 (2015=100)_x           273 non-null    float64
#  278  기타무선통신장비및방송장비 (2015=100)_x     273 non-null    float64
#  279  영상및음향기기 (2015=100)_x           273 non-null    float64
#  280  오디오및음향기기 (2015=100)            273 non-null    float64
#  281  정밀기기 (2015=100)_x              273 non-null    float64
#  282  의료및측정기기 (2015=100)_x           273 non-null    float64
#  283  의료용기기 (2015=100)_x             273 non-null    float64
#  284  측정및분석기기 (2015=100)_x           273 non-null    float64
#  285  기타정밀기기 (2015=100)_x            273 non-null    float64
#  286  사진기및영사기 (2015=100)             273 non-null    float64
#  287  기타광학기기 (2015=100)              273 non-null    float64
#  288  시계 (2015=100)                  273 non-null    float64
#  289  전기장비 (2015=100)_x              273 non-null    float64
#  290  전기장비 (2015=100)_x              273 non-null    float64
#  291  발전기및전동기 (2015=100)_x           273 non-null    float64
#  292  발전기및전동기 (2015=100)_x           273 non-null    float64
#  293  전기변환.공급제어장치 (2015=100)_x       273 non-null    float64
#  294  전기변환장치 (2015=100)_x            273 non-null    float64
#  295  전기회로개폐및접속장치 (2015=100)_x       273 non-null    float64
#  296  배전반및전기자동제어반 (2015=100)         273 non-null    object
#  297  전지 (2015=100)_x                273 non-null    float64
#  298  전지 (2015=100)_x                273 non-null    float64
#  299  전선및케이블 (2015=100)_x            273 non-null    float64
#  300  전선및케이블 (2015=100)_x            273 non-null    float64
#  301  기타전기장비 (2015=100)_x            273 non-null    float64
#  302  전구및램프 (2015=100)_x             273 non-null    float64
#  303  기타전기장비 (2015=100)_x            273 non-null    float64
#  304  기계및장비 (2015=100)_x             273 non-null    float64
#  305  일반목적용기계 (2015=100)_x           273 non-null    float64
#  306  내연기관및터빈 (2015=100)_x           273 non-null    float64
#  307  내연기관및터빈 (2015=100)_x           273 non-null    float64
#  308  펌프및압축기 (2015=100)_x            273 non-null    float64
#  309  펌프및압축기 (2015=100)_x            273 non-null    float64
#  310  일반목적용기계부품 (2015=100)_x         273 non-null    float64
#  311  밸브 (2015=100)_x                273 non-null    float64
#  312  베어링,기어및동력전달장치 (2015=100)_x     273 non-null    float64
#  313  공기및액체조절장치 (2015=100)_x         273 non-null    float64
#  314  공기조절장치및냉장냉동장비 (2015=100)_x     273 non-null    float64
#  315  공기및액체여과기 (2015=100)            273 non-null    float64
#  316  기타일반목적용기계 (2015=100)_x         273 non-null    float64
#  317  기타일반목적용기계 (2015=100)_x         273 non-null    float64
#  318  특수목적용기계 (2015=100)_x           273 non-null    float64
#  319  금속가공용기계 (2015=100)_x           273 non-null    float64
#  320  금속가공용기계 (2015=100)_x           273 non-null    float64
#  321  반도체및디스플레이제조용기계 (2015=100)_x    273 non-null    float64
#  322  반도체제조용기계 (2015=100)_x          273 non-null    float64
#  323  디스플레이제조용기계 (2015=100)_x        273 non-null    object
#  324  기타특수목적용기계 (2015=100)_x         273 non-null    float64
#  325  산업용로봇 (2015=100)               273 non-null    object
#  326  제지및인쇄기계 (2015=100)             273 non-null    float64
#  327  운송장비 (2015=100)_x              273 non-null    float64
#  328  자동차 (2015=100)_x               273 non-null    float64
#  329  자동차 (2015=100)_x               273 non-null    float64
#  330  승용차 (2015=100)_x               273 non-null    float64
#  331  트럭 (2015=100)_x                273 non-null    float64
#  332  자동차부품 (2015=100)_x             273 non-null    float64
#  333  자동차용엔진 (2015=100)_x            273 non-null    float64
#  334  자동차부분품 (2015=100)_x            273 non-null    float64
#  335  기타제조업제품 (2015=100)_x           273 non-null    float64
#  336  기타제조업제품 (2015=100)_x           273 non-null    float64
#  337  가구 (2015=100)_x                273 non-null    float64
#  338  기타가구 (2015=100)_x              273 non-null    float64
#  339  기타제조업제품 (2015=100)_x           273 non-null    float64
#  340  운동및경기용품 (2015=100)             273 non-null    float64
#  341  잎담배 (2015=100)                 201 non-null    object
#  342  제트유 (2015=100)_x               201 non-null    object
#  343  정제혼합용원료유 (2015=100)_x          201 non-null    object
#  344  기타비철금속1차제품 (2015=100)          201 non-null    object
#  345  기타전자부품 (2015=100)              201 non-null    object
#  346  유선통신기기 (2015=100)              201 non-null    object
#  347  장난감및오락용품 (2015=100)            201 non-null    object
#  348  인삼및건강보조식품 (2015=100)           129 non-null    object
#  349  석탄제품 (2015=100)                129 non-null    object
#  350  석탄코크스및석탄관련제품 (2015=100)        129 non-null    object
#  351  기타비금속광물제품 (2015=100)           129 non-null    object
#  352  나사및철선제품 (2015=100)_x           129 non-null    float64
#  353  이동전화기 (2015=100)_x             129 non-null    object
#  354  산업용운반기계 (2016.12=100)          129 non-null    object
#  355  산업용운반기계 (2016.12=100)          129 non-null    object
#  356  가금육 (2017.12=100)              69 non-null     object
#  357  맥주 (2020.12=100)               69 non-null     object
#  358  TV (2021.12=100)               69 non-null     object
#  359  가정용전기기기 (2019.12=100)          69 non-null     object
#  360  기타가정용전기기기 (2019.12=100)        69 non-null     object
#  361  주방용및난방용전기기기 (2020.12=100)      69 non-null     object
#  362  기타운송장비 (2020.12=100)           69 non-null     object
#  363  기타운송장비 (2020.12=100)           69 non-null     object
#  364  모터사이클 (2020.12=100)            69 non-null     object
#  365  총지수 (2015=100)                 273 non-null    float64
#  366  농림수산품 (2015=100)_y             273 non-null    float64
#  367  농림수산품 (2015=100)_y             273 non-null    float64
#  368  농산물 (2015=100)_y               273 non-null    float64
#  369  채소및과실 (2015=100)_y             273 non-null    float64
#  370  과실 (2015=100)_y                273 non-null    float64
#  371  수산물 (2015=100)_y               273 non-null    float64
#  372  신선수산물 (2015=100)_y             273 non-null    float64
#  373  신선어류 (2015=100)_y              273 non-null    float64
#  374  냉동건조수산물 (2015=100)_y           273 non-null    float64
#  375  냉동수산물 (2015=100)_y             273 non-null    float64
#  376  공산품 (2015=100)_y               273 non-null    float64
#  377  음식료품 (2015=100)_y              273 non-null    float64
#  378  식료품 (2015=100)_y               273 non-null    float64
#  379  수산가공품 (2015=100)_y             273 non-null    float64
#  380  수산물가공품 (2015=100)_y            273 non-null    float64
#  381  제당및전분 (2015=100)_y             273 non-null    float64
#  382  정제당 (2015=100)                 273 non-null    float64
#  383  떡,과자및면류 (2015=100)             273 non-null    float64
#  384  면류 (2015=100)                  273 non-null    float64
#  385  기타식료품 (2015.12=100)            273 non-null    float64
#  386  인삼및건강보조식품 (2015.12=100)        273 non-null    float64
#  387  담배 (2015=100)                  273 non-null    float64
#  388  담배 (2015=100)                  273 non-null    float64
#  389  담배 (2015=100)                  273 non-null    float64
#  390  섬유및가죽제품 (2015=100)_y           273 non-null    float64
#  391  섬유및의복 (2015=100)_y             273 non-null    float64
#  392  섬유사 (2015=100)_y               273 non-null    float64
#  393  천연및화학섬유사 (2015=100)_y          273 non-null    float64
#  394  섬유직물 (2015=100)_y              273 non-null    float64
#  395  천연및화학섬유직물 (2015=100)_y         273 non-null    float64
#  396  편조원단 (2015=100)                273 non-null    float64
#  397  직물제품 (2015=100)_y              273 non-null    float64
#  398  부직포및펠트 (2015=100)_y            273 non-null    float64
#  399  기타섬유제품 (2015=100)              273 non-null    float64
#  400  의복제품 (2015=100)_y              273 non-null    float64
#  401  봉제의류 (2015=100)_y              273 non-null    float64
#  402  편조의류 (2015=100)_y              273 non-null    float64
#  403  의복관련장신품 (2015=100)             273 non-null    float64
#  404  가죽제품 (2015=100)_y              273 non-null    float64
#  405  가죽제품 (2015=100)_y              273 non-null    float64
#  406  가죽 (2015=100)_y                273 non-null    float64
#  407  가방및핸드백 (2016.12=100)           273 non-null    float64
#  408  신발 (2015=100)_y                273 non-null    float64
#  409  목재및종이제품 (2015=100)_y           273 non-null    float64
#  410  펄프및종이제품 (2015=100)_y           273 non-null    float64
#  411  종이류 (2015=100)_y               273 non-null    float64
#  412  인쇄용지 (2015=100)_y              273 non-null    float64
#  413  석탄및석유제품 (2015=100)_y           273 non-null    float64
#  414  석탄및석유제품 (2015=100)_y           273 non-null    float64
#  415  원유정제처리제품 (2015=100)_y          273 non-null    float64
#  416  나프타 (2015=100)_y               273 non-null    float64
#  417  휘발유 (2015=100)                 273 non-null    float64
#  418  제트유 (2015=100)_y               273 non-null    float64
#  419  등유 (2015=100)                  273 non-null    float64
#  420  경유 (2015=100)_y                273 non-null    float64
#  421  중유 (2015=100)_y                273 non-null    float64
#  422  정제혼합용원료유 (2015=100)_y          273 non-null    float64
#  423  윤활유및기타석유정제품 (2015=100)         273 non-null    float64
#  424  윤활유및그리스 (2015=100)             273 non-null    float64
#  425  기타석유정제제품 (2015=100)            273 non-null    float64
#  426  화학제품 (2015=100)_y              273 non-null    float64
#  427  기초화학물질 (2015=100)_y            273 non-null    float64
#  428  기초유기화학물질 (2015=100)_y          273 non-null    float64
#  429  지방족기초유분 (2015=100)_y           273 non-null    float64
#  430  방향족기초유분 (2015=100)_y           273 non-null    float64
#  431  석유화학중간제품 (2015=100)_y          273 non-null    float64
#  432  기타기초유기화합물 (2015=100)_y         273 non-null    float64
#  433  기초무기화학물질 (2015.12=100)         273 non-null    float64
#  434  기초무기화합물 (2015.12=100)          273 non-null    float64
#  435  합성수지및합성고무 (2015=100)_y         273 non-null    float64
#  436  합성수지및합성고무 (2015=100)_y         273 non-null    float64
#  437  합성수지 (2015=100)_y              273 non-null    float64
#  438  합성고무 (2015=100)_y              273 non-null    float64
#  439  화학섬유 (2015=100)_y              273 non-null    float64
#  440  화학섬유 (2015=100)_y              273 non-null    float64
#  441  화학섬유 (2015=100)_y              273 non-null    float64
#  442  의약품 (2015.12=100)              273 non-null    float64
#  443  의약품 (2015.12=100)              273 non-null    float64
#  444  의약품 (2015.12=100)              273 non-null    float64
#  445  비료및농약 (2015=100)_y             273 non-null    float64
#  446  비료및농약 (2015=100)_y             273 non-null    float64
#  447  비료및질소화합물 (2015=100)_y          273 non-null    float64
#  448  기타화학제품 (2015=100)_y            273 non-null    float64
#  449  도료및잉크 (2015=100)_y             273 non-null    float64
#  450  도료 (2015=100)_y                273 non-null    float64
#  451  비누및화장품 (2015=100)_y            273 non-null    float64
#  452  비누,세제및치약 (2015=100)            273 non-null    float64
#  453  화장품 (2015=100)_y               273 non-null    float64
#  454  기타화학제품 (2015=100)_y            273 non-null    float64
#  455  접착제및젤라틴 (2015=100)_y           273 non-null    float64
#  456  기타화학제품 (2015=100)_y            273 non-null    float64
#  457  플라스틱제품 (2015=100)_y            273 non-null    float64
#  458  플라스틱1차제품 (2015=100)_y          273 non-null    float64
#  459  플라스틱1차제품 (2015=100)_y          273 non-null    float64
#  460  기타플라스틱제품 (2015=100)            273 non-null    float64
#  461  포장용플라스틱제품 (2015=100)           273 non-null    float64
#  462  고무제품 (2015=100)_y              273 non-null    float64
#  463  타이어및튜브 (2015=100)_y            273 non-null    float64
#  464  타이어및튜브 (2015=100)_y            273 non-null    float64
#  465  기타고무제품 (2019.12=100)           81 non-null     object
#  466  산업용고무제품 (2019.12=100)          81 non-null     object
#  467  비금속광물제품 (2015=100)_y           273 non-null    float64
#  468  기타비금속광물제품 (2015=100)_y         273 non-null    float64
#  469  시멘트 (2015=100)                 273 non-null    float64
#  470  시멘트 (2015=100)                 273 non-null    float64
#  471  기타비금속광물제품 (2015=100)_y         273 non-null    float64
#  472  연마재 (2015=100)                 273 non-null    float64
#  473  제1차금속제품 (2015=100)_y           273 non-null    float64
#  474  철강1차제품 (2015=100)_y            273 non-null    float64
#  475  선철및조강 (2015=100)_y             273 non-null    float64
#  476  합금철 (2015=100)_y               273 non-null    float64
#  477  조강 (2015=100)_y                273 non-null    float64
#  478  열간압연강재 (2015=100)_y            273 non-null    float64
#  479  철근및봉강 (2015=100)_y             273 non-null    float64
#  480  형강 (2015=100)_y                273 non-null    float64
#  481  중후판(두께3mm이상) (2015=100)_y      273 non-null    float64
#  482  열연강판 (2015=100)_y              273 non-null    float64
#  483  철강관 (2015=100)_y               273 non-null    float64
#  484  냉간압연강재 (2015=100)_y            273 non-null    float64
#  485  냉간압연강재 (2015=100)_y            273 non-null    float64
#  486  기타철강1차제품 (2015=100)_y          273 non-null    float64
#  487  표면처리강재 (2015=100)_y            273 non-null    float64
#  488  비철금속괴및1차제품 (2015=100)_y        273 non-null    float64
#  489  비철금속괴 (2015=100)_y             273 non-null    float64
#  490  동제련,정련및합금제품 (2015=100)_y       273 non-null    float64
#  491  연및아연제련,정련및합금제품 (2015=100)_y    273 non-null    float64
#  492  금은괴 (2015=100)_y               273 non-null    float64
#  493  기타비철금속제련,정련및합금제품 (2015=100)_y  273 non-null    float64
#  494  비철금속1차제품 (2015=100)_y          273 non-null    float64
#  495  동1차제품 (2015=100)_y             273 non-null    float64
#  496  알루미늄1차제품 (2015=100)_y          273 non-null    float64
#  497  금속가공제품 (2015=100)_y            273 non-null    float64
#  498  금속가공제품 (2015=100)_y            273 non-null    float64
#  499  구조용금속제품및탱크 (2015=100)          273 non-null    float64
#  500  금속제탱크및압력용기 (2015=100)          273 non-null    float64
#  501  산업용보일러및증기발생기 (2017.12=100)     273 non-null    float64
#  502  기타금속가공제품 (2015=100)_y          273 non-null    float64
#  503  부착용금속제품 (2017.12=100)          273 non-null    float64
#  504  공구류 (2015=100)_y               273 non-null    float64
#  505  나사및철선제품 (2015=100)_y           273 non-null    float64
#  506  기타금속제품 (2015=100)              273 non-null    float64
#  507  컴퓨터,전자및광학기기 (2015=100)_y       273 non-null    float64
#  508  반도체 (2015=100)_y               273 non-null    float64
#  509  반도체 (2015=100)_y               273 non-null    float64
#  510  개별소자 (2015=100)_y              273 non-null    float64
#  511  집적회로 (2015=100)_y              273 non-null    float64
#  512  전자표시장치 (2015=100)_y            273 non-null    float64
#  513  전자표시장치 (2015=100)_y            273 non-null    float64
#  514  LCD평판디스플레이 (2015=100)_y        273 non-null    float64
#  515  기타전자표시장치 (2017.12=100)         273 non-null    float64
#  516  기타전자부품 (2015=100)_y            273 non-null    float64
#  517  인쇄회로기판 (2015=100)_y            273 non-null    float64
#  518  인쇄회로기판및실장기판 (2015=100)_y       273 non-null    float64
#  519  기타전자부품 (2015=100)_y            273 non-null    float64
#  520  축전기,저항기,전자코일및변성기 (2015=100)_y  273 non-null    float64
#  521  컴퓨터및주변기기 (2015=100)_y          273 non-null    float64
#  522  컴퓨터및주변기기 (2015=100)_y          273 non-null    float64
#  523  컴퓨터기억장치 (2015=100)_y           273 non-null    float64
#  524  컴퓨터주변기기 (2015=100)_y           273 non-null    float64
#  525  통신,방송및영상,음향기기 (2015=100)_y     273 non-null    float64
#  526  통신및방송장비 (2015=100)_y           273 non-null    float64
#  527  이동전화기 (2015=100)_y             273 non-null    float64
#  528  기타무선통신장비및방송장비 (2015=100)_y     273 non-null    float64
#  529  영상및음향기기 (2015=100)_y           273 non-null    float64
#  530  TV (2015=100)                  273 non-null    float64
#  531  영상기기 (2015=100)                273 non-null    float64
#  532  정밀기기 (2015=100)_y              273 non-null    float64
#  533  의료및측정기기 (2015=100)_y           273 non-null    float64
#  534  의료용기기 (2015=100)_y             273 non-null    float64
#  535  측정및분석기기 (2015=100)_y           273 non-null    float64
#  536  기타정밀기기 (2015=100)_y            273 non-null    float64
#  537  기타광학기기 (2017.12=100)           273 non-null    float64
#  538  전기장비 (2015=100)_y              273 non-null    float64
#  539  전기장비 (2015=100)_y              273 non-null    float64
#  540  발전기및전동기 (2015=100)_y           273 non-null    float64
#  541  발전기및전동기 (2015=100)_y           273 non-null    float64
#  542  전기변환.공급제어장치 (2015=100)_y       273 non-null    float64
#  543  변압기 (2015=100)                 273 non-null    float64
#  544  전기변환장치 (2015=100)_y            273 non-null    float64
#  545  전기회로개폐및접속장치 (2015=100)_y       273 non-null    float64
#  546  배전반및전기자동제어반 (2017.12=100)      273 non-null    float64
#  547  전지 (2015=100)_y                273 non-null    float64
#  548  전지 (2015=100)_y                273 non-null    float64
#  549  전선및케이블 (2015=100)_y            273 non-null    float64
#  550  전선및케이블 (2015=100)_y            273 non-null    float64
#  551  가정용전기기기 (2015=100)             273 non-null    float64
#  552  가정용냉장고및냉동고 (2015=100)          273 non-null    float64
#  553  주방용및난방용전기기기 (2019.12=100)      81 non-null     object
#  554  기타가정용전기기기 (2015=100)           273 non-null    float64
#  555  기타전기장비 (2015=100)_y            273 non-null    float64
#  556  전구및램프 (2015=100)_y             273 non-null    float64
#  557  기타전기장비 (2015=100)_y            273 non-null    float64
#  558  기계및장비 (2015=100)_y             273 non-null    float64
#  559  일반목적용기계 (2015=100)_y           273 non-null    float64
#  560  내연기관및터빈 (2015=100)_y           273 non-null    float64
#  561  내연기관및터빈 (2015=100)_y           273 non-null    float64
#  562  펌프및압축기 (2015=100)_y            273 non-null    float64
#  563  펌프및압축기 (2015=100)_y            273 non-null    float64
#  564  일반목적용기계부품 (2015=100)_y         273 non-null    float64
#  565  밸브 (2015=100)_y                273 non-null    float64
#  566  베어링,기어및동력전달장치 (2015=100)_y     273 non-null    float64
#  567  산업용운반기계 (2015=100)             273 non-null    float64
#  568  산업용운반기계 (2015=100)             273 non-null    float64
#  569  공기및액체조절장치 (2015=100)_y         273 non-null    float64
#  570  공기조절장치및냉장냉동장비 (2015=100)_y     273 non-null    float64
#  571  기타일반목적용기계 (2015=100)_y         273 non-null    float64
#  572  사무용기기 (2015=100)               273 non-null    float64
#  573  기타일반목적용기계 (2015=100)_y         273 non-null    float64
#  574  특수목적용기계 (2015=100)_y           273 non-null    float64
#  575  농업및건설용기계 (2015=100)            273 non-null    float64
#  576  농업용기계 (2015=100)               273 non-null    float64
#  577  건설및광물처리기계 (2015=100)           273 non-null    float64
#  578  금속가공용기계 (2015=100)_y           273 non-null    float64
#  579  금속가공용기계 (2015=100)_y           273 non-null    float64
#  580  반도체및디스플레이제조용기계 (2015=100)_y    273 non-null    float64
#  581  반도체제조용기계 (2015=100)_y          273 non-null    float64
#  582  디스플레이제조용기계 (2015=100)_y        273 non-null    float64
#  583  기타특수목적용기계 (2015=100)_y         273 non-null    float64
#  584  기타특수목적용기계 (2015=100)           273 non-null    float64
#  585  운송장비 (2015=100)_y              273 non-null    float64
#  586  자동차 (2015=100)_y               273 non-null    float64
#  587  자동차 (2015=100)_y               273 non-null    float64
#  588  승용차 (2015=100)_y               273 non-null    float64
#  589  버스 (2015=100)                  273 non-null    float64
#  590  트럭 (2015=100)_y                273 non-null    float64
#  591  특장차및트레일러 (2017.12=100)         273 non-null    float64
#  592  특장차 (2017.12=100)              273 non-null    float64
#  593  자동차부품 (2015=100)_y             273 non-null    float64
#  594  자동차용엔진 (2015=100)_y            273 non-null    float64
#  595  자동차부분품 (2015=100)_y            273 non-null    float64
#  596  기타제조업제품 (2015=100)_y           273 non-null    float64
#  597  기타제조업제품 (2015=100)_y           273 non-null    float64
#  598  가구 (2015=100)_y                273 non-null    float64
#  599  금속가구 (2015=100)                273 non-null    float64
#  600  기타가구 (2015=100)_y              273 non-null    float64
#  601  기타제조업제품 (2015=100)_y           273 non-null    float64
#  602  기타제조업제품 (2015=100)             273 non-null    float64
#  603  총지수                            273 non-null    float64
#  604  식료품 및 에너지제외 지수                 273 non-null    float64
#  605  식료품 및 에너지                      273 non-null    object
#  606  보통휘발유                          261 non-null    float64
#  607  실내등유                           261 non-null    float64
#  608  보일러등유                          261 non-null    object
#  609  자동차용 경유                        261 non-null    float64
# dtypes: float64(548), object(62)
# memory usage: 1.4+ MB

# %%
# 앞에 값으로 결측치 처리
samil_df = samil_df.fillna(method='ffill')
samil_df = samil_df.fillna(method='bfill')

# %%
samil_df
# Out:
#        month  Samil_Close  Samil_Change  Kospi_Close  Kospi_Change  label  \
# 0    2000-01     0.166849      0.466341     0.166989     -0.003865    0.0
# 1    2000-02     0.151669      0.509320     0.150465     -0.006220    0.0
# 2    2000-03     0.283741      0.872881     0.141921      0.002064    0.0
# 3    2000-04     0.305151      0.329995     0.107834     -0.008667    1.0
# 4    2000-05     0.242085      0.337147     0.086009      0.000940    1.0
# ..       ...          ...           ...          ...           ...    ...
# 291  2022-06     0.141677      0.283132     0.704787     -0.006930    0.0
# 292  2022-07     0.122400      0.520008     0.665200      0.002419    1.0
# 293  2022-08     0.139956      0.425427     0.707168      0.000423    0.0
# 294  2022-09     0.113694      0.317581     0.656375     -0.006745    0.0
# 295  2022-10     0.095258      0.476417     0.612482      0.004145    0.0
#
#      선행종합지수(2015=100) 재고순환지표(%p) 경제심리지수 기계류내수출하지수(선박제외)(2015=100)  ...  \
# 0                58.5       -0.4  101.4                      88.7  ...
# 1                58.7       -0.4  101.4                      88.7  ...
# 2                59.0       -0.4  101.4                      88.7  ...
# 3                58.8       -0.4  101.4                      88.7  ...
# 4                58.8       -0.4  101.4                      88.7  ...
# ..                ...        ...    ...                       ...  ...
# 291             129.2      -14.2  105.0                      99.7  ...
# 292             129.4      -15.4  102.3                     103.0  ...
# 293             129.5      -16.1   99.9                     105.8  ...
# 294             129.5      -16.1   99.9                     105.8  ...
# 295             129.5      -16.1   99.9                     105.8  ...
#
#     기타가구 (2015=100)_y 기타제조업제품 (2015=100)_y 기타제조업제품 (2015=100)      총지수  \
# 0               60.23                78.87              78.23   62.456
# 1               60.23                78.78              78.23   62.647
# 2               60.23                78.84              78.23   62.962
# 3               60.23                78.87              78.23   62.709
# 4               60.23                78.81              78.23   62.393
# ..                ...                  ...                ...      ...
# 291            116.86               109.24             109.24  108.220
# 292            116.86               121.19             121.19  108.740
# 293            116.86               121.19             121.19  108.620
# 294            116.86               121.19             121.19  108.930
# 295            116.86               121.19             121.19  108.930
#
#      식료품 및 에너지제외 지수 식료품 및 에너지    보통휘발유     실내등유   보일러등유  자동차용 경유
# 0            64.697    85.829  1287.02   613.60  606.52   660.99
# 1            64.828    85.829  1287.02   613.60  606.52   660.99
# 2            65.286    85.829  1287.02   613.60  606.52   660.99
# 3            65.352    85.829  1287.02   613.60  606.52   660.99
# 4            65.156    85.829  1287.02   613.60  606.52   660.99
# ..              ...       ...      ...      ...     ...      ...
# 291         105.040    119.26  2084.00  1601.77  1357.0  2089.03
# 292         105.430    120.23  2029.99  1686.55  1357.0  2084.91
# 293         105.760    118.54  1792.19  1639.49  1357.0  1889.31
# 294         105.710    120.12  1730.00  1620.15  1357.0  1850.20
# 295         105.710    120.12  1730.00  1620.15  1357.0  1850.20
#
# [296 rows x 610 columns]

# %%
samil_df.isnull().sum()
# Out:
# month           0
# Samil_Close     0
# Samil_Change    0
# Kospi_Close     0
# Kospi_Change    0
#                ..
# 식료품 및 에너지       0
# 보통휘발유           0
# 실내등유            0
# 보일러등유           0
# 자동차용 경유         0
# Length: 610, dtype: int64

# %%
df = samil_df

# %%
# 월 평균값을 내셨다면 안해도 되는 코드들입니다.
# 데이터프레임에 월별주가평균, 코스피월별평균만 있으면 됩니다.
# 월 평균 값만 남기고 나머지 빈칸 있는 행 삭제
# df = pd.read_csv('data/9_emart주가_월평균.csv')
# df = df.dropna()
# df.date = pd.to_datetime(df.date)
# df['date'] = df['date'].dt.strftime('%Y-%m')
# df = df.set_index('date')
# df = df.reset_index('date')
'''
# 월 평균값 있을때
df = pd.read_csv('data/10_emart - 주가,코스피원본.csv')
df.date = pd.to_datetime(df.date)
df['date'] = df['date'].dt.strftime('%Y-%m')
df = df.set_index('date')
'''

# MinMaxScaler 데이터 정규화
scaler = MinMaxScaler()
df = df.set_index('month')
scaler.fit(df)
scaled = scaler.transform(df)
df_scaled = pd.DataFrame(scaled, columns=df.columns)

df = df.reset_index()
df_scaled.insert(0,'month', df['month'] )

df_scaled
# df = df.merge(df_scaled,how='left')
# df.head()
# Out:
#        month  Samil_Close  Samil_Change  Kospi_Close  Kospi_Change  label  \
# 0    2000-01     0.166849      0.466341     0.159749      0.307588    0.0
# 1    2000-02     0.151669      0.509320     0.142720      0.199083    0.0
# 2    2000-03     0.283741      0.872881     0.133917      0.580746    0.0
# 3    2000-04     0.305151      0.329995     0.098791      0.086354    1.0
# 4    2000-05     0.242085      0.337147     0.076302      0.528975    1.0
# ..       ...          ...           ...          ...           ...    ...
# 291  2022-06     0.141677      0.283132     0.713928      0.166370    0.0
# 292  2022-07     0.122400      0.520008     0.673135      0.597121    1.0
# 293  2022-08     0.139956      0.425427     0.716381      0.505142    0.0
# 294  2022-09     0.113694      0.317581     0.664041      0.174894    0.0
# 295  2022-10     0.095258      0.476417     0.618811      0.676664    0.0
#
#      선행종합지수(2015=100)  재고순환지표(%p)    경제심리지수  기계류내수출하지수(선박제외)(2015=100)  ...  \
# 0            0.031378    0.437050  0.712329                   0.245478  ...
# 1            0.034106    0.437050  0.712329                   0.245478  ...
# 2            0.038199    0.437050  0.712329                   0.245478  ...
# 3            0.035471    0.437050  0.712329                   0.245478  ...
# 4            0.035471    0.437050  0.712329                   0.245478  ...
# ..                ...         ...       ...                        ...  ...
# 291          0.995907    0.188849  0.782779                   0.529716  ...
# 292          0.998636    0.167266  0.729941                   0.614987  ...
# 293          1.000000    0.154676  0.682975                   0.687339  ...
# 294          1.000000    0.154676  0.682975                   0.687339  ...
# 295          1.000000    0.154676  0.682975                   0.687339  ...
#
#      기타가구 (2015=100)_y  기타제조업제품 (2015=100)_y  기타제조업제품 (2015=100)       총지수  \
# 0                  0.0              0.124353            0.083618  0.001354
# 1                  0.0              0.122491            0.083618  0.005458
# 2                  0.0              0.123733            0.083618  0.012227
# 3                  0.0              0.124353            0.083618  0.006790
# 4                  0.0              0.123112            0.083618  0.000000
# ..                 ...                   ...                 ...       ...
# 291                1.0              0.752742            0.745094  0.984743
# 292                1.0              1.000000            1.000000  0.995917
# 293                1.0              1.000000            1.000000  0.993339
# 294                1.0              1.000000            1.000000  1.000000
# 295                1.0              1.000000            1.000000  1.000000
#
#      식료품 및 에너지제외 지수  식료품 및 에너지     보통휘발유      실내등유     보일러등유   자동차용 경유
# 0          0.000000   0.000000  0.077708  0.095603  0.107626  0.050417
# 1          0.003190   0.000000  0.077708  0.095603  0.107626  0.050417
# 2          0.014344   0.000000  0.077708  0.095603  0.107626  0.050417
# 3          0.015951   0.000000  0.077708  0.095603  0.107626  0.050417
# 4          0.011178   0.000000  0.077708  0.095603  0.107626  0.050417
# ..              ...        ...       ...       ...       ...       ...
# 291        0.982466   0.971803  1.000000  0.928538  0.822539  1.000000
# 292        0.991964   1.000000  0.937498  1.000000  0.822539  0.997260
# 293        1.000000   0.950874  0.662308  0.960333  0.822539  0.867195
# 294        0.998782   0.996802  0.590339  0.944031  0.822539  0.841189
# 295        0.998782   0.996802  0.590339  0.944031  0.822539  0.841189
#
# [296 rows x 610 columns]

# %%
a = 50
df_scaled_ = df_scaled[:a]

# %%
# 주가 데이터 그래프

data = df_scaled

plt.figure(figsize=(20, 10))
plt.rcParams['font.family'] = 'AppleGothic'

# plt.subplot(2, 1, 1)
# plt.axhline(y=0, color='black', linewidth=1)
ax = sns.lineplot(data=data, x="month", y='Samil_Close', label='samil_price', color='brown')
ax = sns.lineplot(data=data, x="month", y='Kospi_Close', label='kospi_price', color='blue')
ax = sns.scatterplot(data=data, x="month", y="label", label='↓', color='black')

'''
plt.subplot(2, 1, 1)
plt.figure(figsize=(20, 10))
plt.axhline(y=0, color='r', linewidth=1)
sns.lineplot(data=data3, x="Date", y='Kospi_Change', label='kospi_change', color='orange')
sns.lineplot(data=data3, x='Date', y='CJ_Change', label='cj_change', color='skyBlue')
'''

total_len = len(data.index)
ax.set_xticks(np.arange(0, total_len + 1, 15))

plt.show()


'''
# 주가 데이터 그래프
plt.figure(figsize=(15, 6))
plt.rcParams['font.family'] = 'AppleGothic'

sns.lineplot(data=df, x="date", y="k_s - p_s", label='하락정도')
sns.scatterplot(data=df, x="date", y="downturn", label='주가하락세')
sns.lineplot(data=df, x="date", y="pricemm", label='price_minmax')
sns.lineplot(data=df, x="date", y="kospimm", label='kospi_minmax')

plt.ylabel('')
plt.xticks(rotation=45)

plt.show()
'''
# Out:
# '\n# 주가 데이터 그래프\nplt.figure(figsize=(15, 6))\nplt.rcParams[\'font.family\'] = \'AppleGothic\'\n\nsns.lineplot(data=df, x="date", y="k_s - p_s", label=\'하락정도\')\nsns.scatterplot(data=df, x="date", y="downturn", label=\'주가하락세\')\nsns.lineplot(data=df, x="date", y="pricemm", label=\'price_minmax\')\nsns.lineplot(data=df, x="date", y="kospimm", label=\'kospi_minmax\')\n\nplt.ylabel(\'\')\nplt.xticks(rotation=45)\n\nplt.show()\n'

# %%
df.to_csv('yvalue.csv',index=False)

# %% [markdown]
# - 저장해서 액셀로 켜시고 https://docs.google.com/spreadsheets/d/1fgvvsrypJKAZEljnHw-BNQsWu9WNRNBAtiMUwEad9Sc/edit#gid=1221057598 이 파일을 복사해서 각 시트에 y값('downturn'열)을 만든 데이터로 대체하시면 됩니다.
# - downturn이 target(y값) feature입니다. 이것만 date 열 오른쪽에 남기고, 그 오른쪽에 필요한 feature를 추가하면 됩니다.
# - 카테고리별로 시트를 나눠놨으니 그 시트에 바로 복붙하세요

# %% [markdown]
# ### feature importance로 feature selection

# %%
df = df_scaled.set_index('month')

# %%
df
# Out:
#          Samil_Close  Samil_Change  Kospi_Close  Kospi_Change  label  \
# month
# 2000-01     0.166849      0.466341     0.159749      0.307588    0.0
# 2000-02     0.151669      0.509320     0.142720      0.199083    0.0
# 2000-03     0.283741      0.872881     0.133917      0.580746    0.0
# 2000-04     0.305151      0.329995     0.098791      0.086354    1.0
# 2000-05     0.242085      0.337147     0.076302      0.528975    1.0
# ...              ...           ...          ...           ...    ...
# 2022-06     0.141677      0.283132     0.713928      0.166370    0.0
# 2022-07     0.122400      0.520008     0.673135      0.597121    1.0
# 2022-08     0.139956      0.425427     0.716381      0.505142    0.0
# 2022-09     0.113694      0.317581     0.664041      0.174894    0.0
# 2022-10     0.095258      0.476417     0.618811      0.676664    0.0
#
#          선행종합지수(2015=100)  재고순환지표(%p)    경제심리지수  기계류내수출하지수(선박제외)(2015=100)  \
# month
# 2000-01          0.031378    0.437050  0.712329                   0.245478
# 2000-02          0.034106    0.437050  0.712329                   0.245478
# 2000-03          0.038199    0.437050  0.712329                   0.245478
# 2000-04          0.035471    0.437050  0.712329                   0.245478
# 2000-05          0.035471    0.437050  0.712329                   0.245478
# ...                   ...         ...       ...                        ...
# 2022-06          0.995907    0.188849  0.782779                   0.529716
# 2022-07          0.998636    0.167266  0.729941                   0.614987
# 2022-08          1.000000    0.154676  0.682975                   0.687339
# 2022-09          1.000000    0.154676  0.682975                   0.687339
# 2022-10          1.000000    0.154676  0.682975                   0.687339
#
#          건설수주액(실질)(십억원)  ...  기타가구 (2015=100)_y  기타제조업제품 (2015=100)_y  \
# month                    ...
# 2000-01        0.222511  ...                0.0              0.124353
# 2000-02        0.222511  ...                0.0              0.122491
# 2000-03        0.222511  ...                0.0              0.123733
# 2000-04        0.222511  ...                0.0              0.124353
# 2000-05        0.222511  ...                0.0              0.123112
# ...                 ...  ...                ...                   ...
# 2022-06        0.862189  ...                1.0              0.752742
# 2022-07        1.000000  ...                1.0              1.000000
# 2022-08        0.933958  ...                1.0              1.000000
# 2022-09        0.933958  ...                1.0              1.000000
# 2022-10        0.933958  ...                1.0              1.000000
#
#          기타제조업제품 (2015=100)       총지수  식료품 및 에너지제외 지수  식료품 및 에너지     보통휘발유  \
# month
# 2000-01            0.083618  0.001354        0.000000   0.000000  0.077708
# 2000-02            0.083618  0.005458        0.003190   0.000000  0.077708
# 2000-03            0.083618  0.012227        0.014344   0.000000  0.077708
# 2000-04            0.083618  0.006790        0.015951   0.000000  0.077708
# 2000-05            0.083618  0.000000        0.011178   0.000000  0.077708
# ...                     ...       ...             ...        ...       ...
# 2022-06            0.745094  0.984743        0.982466   0.971803  1.000000
# 2022-07            1.000000  0.995917        0.991964   1.000000  0.937498
# 2022-08            1.000000  0.993339        1.000000   0.950874  0.662308
# 2022-09            1.000000  1.000000        0.998782   0.996802  0.590339
# 2022-10            1.000000  1.000000        0.998782   0.996802  0.590339
#
#              실내등유     보일러등유   자동차용 경유
# month
# 2000-01  0.095603  0.107626  0.050417
# 2000-02  0.095603  0.107626  0.050417
# 2000-03  0.095603  0.107626  0.050417
# 2000-04  0.095603  0.107626  0.050417
# 2000-05  0.095603  0.107626  0.050417
# ...           ...       ...       ...
# 2022-06  0.928538  0.822539  1.000000
# 2022-07  1.000000  0.822539  0.997260
# 2022-08  0.960333  0.822539  0.867195
# 2022-09  0.944031  0.822539  0.841189
# 2022-10  0.944031  0.822539  0.841189
#
# [296 rows x 609 columns]

# %%
df.iloc[:,5:]
# Out:
#          선행종합지수(2015=100)  재고순환지표(%p)    경제심리지수  기계류내수출하지수(선박제외)(2015=100)  \
# month
# 2000-01          0.031378    0.437050  0.712329                   0.245478
# 2000-02          0.034106    0.437050  0.712329                   0.245478
# 2000-03          0.038199    0.437050  0.712329                   0.245478
# 2000-04          0.035471    0.437050  0.712329                   0.245478
# 2000-05          0.035471    0.437050  0.712329                   0.245478
# ...                   ...         ...       ...                        ...
# 2022-06          0.995907    0.188849  0.782779                   0.529716
# 2022-07          0.998636    0.167266  0.729941                   0.614987
# 2022-08          1.000000    0.154676  0.682975                   0.687339
# 2022-09          1.000000    0.154676  0.682975                   0.687339
# 2022-10          1.000000    0.154676  0.682975                   0.687339
#
#          건설수주액(실질)(십억원)  수출입물가비율(2015=100)  코스피(1980.1.4=100)  장단기금리차(%p)  \
# month
# 2000-01        0.222511           0.950000           0.010843    0.393651
# 2000-02        0.222511           0.950000           0.010843    0.393651
# 2000-03        0.222511           0.950000           0.010843    0.393651
# 2000-04        0.222511           0.950000           0.010843    0.393651
# 2000-05        0.222511           0.950000           0.010843    0.393651
# ...                 ...                ...                ...         ...
# 2022-06        0.862189           0.030882           0.762839    0.657143
# 2022-07        1.000000           0.030882           0.720105    0.603175
# 2022-08        0.933958           0.032353           0.701431    0.533333
# 2022-09        0.933958           0.032353           0.701431    0.533333
# 2022-10        0.933958           0.032353           0.701431    0.533333
#
#          동행종합지수(2015=100)  광공업생산지수(2015=100)  ...  기타가구 (2015=100)_y  \
# month                                         ...
# 2000-01          0.000000           0.000000  ...                0.0
# 2000-02          0.004237           0.000000  ...                0.0
# 2000-03          0.009887           0.000000  ...                0.0
# 2000-04          0.016949           0.000000  ...                0.0
# 2000-05          0.024011           0.000000  ...                0.0
# ...                   ...                ...  ...                ...
# 2022-06          0.975989           0.970814  ...                1.0
# 2022-07          0.987288           0.975422  ...                1.0
# 2022-08          1.000000           0.966206  ...                1.0
# 2022-09          1.000000           0.966206  ...                1.0
# 2022-10          1.000000           0.966206  ...                1.0
#
#          기타제조업제품 (2015=100)_y  기타제조업제품 (2015=100)       총지수  식료품 및 에너지제외 지수  \
# month
# 2000-01              0.124353            0.083618  0.001354        0.000000
# 2000-02              0.122491            0.083618  0.005458        0.003190
# 2000-03              0.123733            0.083618  0.012227        0.014344
# 2000-04              0.124353            0.083618  0.006790        0.015951
# 2000-05              0.123112            0.083618  0.000000        0.011178
# ...                       ...                 ...       ...             ...
# 2022-06              0.752742            0.745094  0.984743        0.982466
# 2022-07              1.000000            1.000000  0.995917        0.991964
# 2022-08              1.000000            1.000000  0.993339        1.000000
# 2022-09              1.000000            1.000000  1.000000        0.998782
# 2022-10              1.000000            1.000000  1.000000        0.998782
#
#          식료품 및 에너지     보통휘발유      실내등유     보일러등유   자동차용 경유
# month
# 2000-01   0.000000  0.077708  0.095603  0.107626  0.050417
# 2000-02   0.000000  0.077708  0.095603  0.107626  0.050417
# 2000-03   0.000000  0.077708  0.095603  0.107626  0.050417
# 2000-04   0.000000  0.077708  0.095603  0.107626  0.050417
# 2000-05   0.000000  0.077708  0.095603  0.107626  0.050417
# ...            ...       ...       ...       ...       ...
# 2022-06   0.971803  1.000000  0.928538  0.822539  1.000000
# 2022-07   1.000000  0.937498  1.000000  0.822539  0.997260
# 2022-08   0.950874  0.662308  0.960333  0.822539  0.867195
# 2022-09   0.996802  0.590339  0.944031  0.822539  0.841189
# 2022-10   0.996802  0.590339  0.944031  0.822539  0.841189
#
# [296 rows x 604 columns]

# %%
'''
# 데이터 불러오기 및 날짜 인덱스 지정
df = pd.read_csv('data/10_emart - 동행&후행.csv') # 파일 경로를 수정해주세요
df.date = pd.to_datetime(df.date)
df = df.set_index('date')
df = df.drop(['k_s - p_s'], axis=1)
'''

from sklearn.tree import DecisionTreeClassifier

# train, test split (8:2)
X_train, X_test, y_train, y_test = train_test_split(df.iloc[:,5:], df['label'], test_size=0.2, random_state=0)
train_cnt = y_train.count()
test_cnt = y_test.count()
print(X_train.shape)
print(X_test.shape)

# 0,1이 고르게 나누어졌을까?
print(y_train.value_counts()/train_cnt)
print(y_test.value_counts()/test_cnt)

# CART 모델 학습
model = DecisionTreeClassifier(max_depth=3, random_state=1)
model.fit(X_train, y_train)

# predict
y_pred = model.predict(X_test)
print('정확도 : ', accuracy_score(y_pred, y_test))

# feature importance 확인
ftr_importances = pd.Series(model.feature_importances_, index = X_train.columns)

ftr_top5 = ftr_importances.sort_values(ascending=False)[:20]

plt.figure(figsize=(8,6))
plt.rcParams['font.family'] = 'AppleGothic'
plt.title('Feature Importances') # 그래프 제목을 변경해주세요
sns.barplot(x=ftr_top5, y=ftr_top5.index)
plt.show()
# Out:
# (236, 604)
# (60, 604)
# 1.0    0.605932
# 0.0    0.394068
# Name: label, dtype: float64
# 1.0    0.516667
# 0.0    0.483333
# Name: label, dtype: float64
# 정확도 :  0.6333333333333333

# %%
plt.pcolor(df)
plt.xticks(np.arange(0.5, len(df.columns), 1), df.columns)
plt.yticks(np.arange(0.5, len(df.index), 1), df.index)
plt.title('Heatmap by plt.pcolor()', fontsize=20)
# plt.xlabel('Year', fontsize=14)
# plt.ylabel('Month', fontsize=14)
plt.colorbar()
plt.show()

# %% [markdown]
# - 이런 식으로 상위에 뜬 feature만 selection해서 새로운 데이터 프레임을 만듭니다(액셀 작업 추천)
# - accuracy가 0.7 이 넘는 데이터에서 나온 feature를 넣는게 좋았던 것 같습니다.

# %%
# 데이터 불러오기 및 날짜 인덱스 지정
df = pd.read_csv('data/10_emart - selection.csv')
df.date = pd.to_datetime(df.date)
df = df.set_index('date')
df = df.drop(['k_s - p_s'], axis=1)

from sklearn.tree import DecisionTreeClassifier

# train, test split
X_train, X_test, y_train, y_test = train_test_split(df.iloc[:,1:], df['downturn'], test_size=0.2, random_state=0)
train_cnt = y_train.count()
test_cnt = y_test.count()
print(X_train.shape)
print(X_test.shape)

print(y_train.value_counts()/train_cnt)
print(y_test.value_counts()/test_cnt)

# CART 모델
model = DecisionTreeClassifier(max_depth=4, random_state=1)
model.fit(X_train, y_train)
# model.fit(X_train_resampled, y_train_resampled)

y_pred = model.predict(X_test)
print('정확도 : ',accuracy_score(y_pred, y_test))

ftr_importances = pd.Series(model.feature_importances_, index = X_train.columns)

ftr_top5 = ftr_importances.sort_values(ascending=False)[:20]

plt.figure(figsize=(8,6))
plt.rcParams['font.family'] = 'AppleGothic'
plt.title('Selected Feature Importances')
sns.barplot(x=ftr_top5, y=ftr_top5.index)
plt.show()
# Out:
# (44, 13)
# (12, 13)
# 1    0.659091
# 0    0.340909
# Name: downturn, dtype: float64
# 0    0.5
# 1    0.5
# Name: downturn, dtype: float64
# 정확도 :  0.8333333333333334

# %% [markdown]
# #### 하락 팩터 찾기

# %%
## feature selection된 데이터 MinMaxScaling

# 데이터 불러오기 및 날짜 인덱스 지정
df_apr_f = pd.read_csv('data/9_에이피알 - features.csv')
df_apr_f.date = pd.to_datetime(df_apr_f.date)
df_apr_f = df_apr_f.ffill()
# df = df_apr_f.drop(['생산자제품재고지수','신선어개류 물가'], axis=1)
# df_onlyfeat = df_apr_f.drop(['emart_close', 'kospi_close', 'emartMinMax', 'kospiMinMax', 'k-p_diff', 'k_p10'], axis=1)
df_apr_f = df_apr_f.set_index('date')
df_apr_ff = df_apr_f.drop('소비자 거래지수', axis=1)

# MinMaxScaler로 price, kospi 데이터 정규화
scaler = MinMaxScaler()
scaler.fit(df_apr_ff)
scaled = scaler.transform(df_apr_ff)
df_scaled = pd.DataFrame(scaled, columns=['생산자제품재고지수(전월비)(%)','신선어개','트래픽','소비자 거래건수'])

# 정규화한 데이터에 날짜 열 추가
# df_onlyfeat = df_onlyfeat.reset_index()
df_scaled.insert(0,'date', df['date'] )

# 원본데이터에 merge
df_apr_f = df_apr_f.drop(df_apr_f.iloc[:,:4], axis=1)
df_apr_f = df_apr_f.reset_index()
df_apr_f = df_apr_f.merge(df_scaled, how='left')

df_apr_f = df.merge(df_apr_f, how='left')

df_apr_f.head()
